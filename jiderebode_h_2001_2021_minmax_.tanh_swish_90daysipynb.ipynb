# %%
# import all libraries and modules
import tensorflow as tf 
import pandas as pd  
import numpy as np    
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import ConvLSTM2D, Dropout
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import QuantileTransformer, StandardScaler, MinMaxScaler
tf.random.set_seed(123)
np.random.seed(123)
import datetime
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import set_config
import hydroeval as he

# %%
# tensorflow version
tf.__version__
# Out:
# '2.4.1'

# %%
plt.style.use('seaborn-whitegrid')
plt.rcParams['figure.figsize'] = (16, 9)

# %%
fn = '/home/jefire/project/water/input/jide_q_h_data/jiderebode_h_imerge_data_2000_2021.csv'

# %%
df = pd.read_csv(fn)
df
# Out:
#             date      Pt-59      Rt-207         Tt     Tt-129    Tavgt-6  \
# 0     2000-12-24   0.024893  806.227441  22.162928  28.957788  22.065407
# 1     2000-12-25   0.024559  804.305827  22.137035  28.277483  22.060858
# 2     2000-12-26   0.082533  804.002595  22.514109  27.742418  22.142795
# 3     2000-12-27   0.180188  797.916736  22.487470  28.105324  22.226715
# 4     2000-12-28   0.085362  785.459225  22.716461  29.599943  22.318781
# ...          ...        ...         ...        ...        ...        ...
# 7581  2021-09-26   9.375081  852.617897  31.067743  34.296530  30.655116
# 7582  2021-09-27   8.460711  853.379331  30.464815  34.135807  30.533431
# 7583  2021-09-28  12.678004  853.541427  30.405666  34.440166  30.548318
# 7584  2021-09-29   6.628835  857.843422  30.473732  34.654995  30.650742
# 7585  2021-09-30   7.453531  863.134363  29.751686  34.584763  30.500594
#
#       Tavgt-220       H
# 0     28.769083  331.75
# 1     28.714231  332.74
# 2     28.662624  333.00
# 3     28.612342  333.49
# 4     28.564346  334.00
# ...         ...     ...
# 7581  31.219590  438.00
# 7582  31.252320  435.00
# 7583  31.282351  430.00
# 7584  31.310892  425.00
# 7585  31.335883  421.00
#
# [7586 rows x 8 columns]

# %%
# make a copy of the Dataframe
df_copy = df.copy()
df_copy
# Out:
#             date      Pt-59      Rt-207         Tt     Tt-129    Tavgt-6  \
# 0     2000-12-24   0.024893  806.227441  22.162928  28.957788  22.065407
# 1     2000-12-25   0.024559  804.305827  22.137035  28.277483  22.060858
# 2     2000-12-26   0.082533  804.002595  22.514109  27.742418  22.142795
# 3     2000-12-27   0.180188  797.916736  22.487470  28.105324  22.226715
# 4     2000-12-28   0.085362  785.459225  22.716461  29.599943  22.318781
# ...          ...        ...         ...        ...        ...        ...
# 7581  2021-09-26   9.375081  852.617897  31.067743  34.296530  30.655116
# 7582  2021-09-27   8.460711  853.379331  30.464815  34.135807  30.533431
# 7583  2021-09-28  12.678004  853.541427  30.405666  34.440166  30.548318
# 7584  2021-09-29   6.628835  857.843422  30.473732  34.654995  30.650742
# 7585  2021-09-30   7.453531  863.134363  29.751686  34.584763  30.500594
#
#       Tavgt-220       H
# 0     28.769083  331.75
# 1     28.714231  332.74
# 2     28.662624  333.00
# 3     28.612342  333.49
# 4     28.564346  334.00
# ...         ...     ...
# 7581  31.219590  438.00
# 7582  31.252320  435.00
# 7583  31.282351  430.00
# 7584  31.310892  425.00
# 7585  31.335883  421.00
#
# [7586 rows x 8 columns]

# %%
# convert to datetime object
df_copy.date = pd.to_datetime(df_copy.date, dayfirst = False)
df_copy
# Out:
#            date      Pt-59      Rt-207         Tt     Tt-129    Tavgt-6  \
# 0    2000-12-24   0.024893  806.227441  22.162928  28.957788  22.065407
# 1    2000-12-25   0.024559  804.305827  22.137035  28.277483  22.060858
# 2    2000-12-26   0.082533  804.002595  22.514109  27.742418  22.142795
# 3    2000-12-27   0.180188  797.916736  22.487470  28.105324  22.226715
# 4    2000-12-28   0.085362  785.459225  22.716461  29.599943  22.318781
# ...         ...        ...         ...        ...        ...        ...
# 7581 2021-09-26   9.375081  852.617897  31.067743  34.296530  30.655116
# 7582 2021-09-27   8.460711  853.379331  30.464815  34.135807  30.533431
# 7583 2021-09-28  12.678004  853.541427  30.405666  34.440166  30.548318
# 7584 2021-09-29   6.628835  857.843422  30.473732  34.654995  30.650742
# 7585 2021-09-30   7.453531  863.134363  29.751686  34.584763  30.500594
#
#       Tavgt-220       H
# 0     28.769083  331.75
# 1     28.714231  332.74
# 2     28.662624  333.00
# 3     28.612342  333.49
# 4     28.564346  334.00
# ...         ...     ...
# 7581  31.219590  438.00
# 7582  31.252320  435.00
# 7583  31.282351  430.00
# 7584  31.310892  425.00
# 7585  31.335883  421.00
#
# [7586 rows x 8 columns]

# %%
# get summary statistics
df_copy.describe()
# Out:
#              Pt-59       Rt-207           Tt       Tt-129      Tavgt-6  \
# count  7586.000000  7586.000000  7586.000000  7586.000000  7586.000000
# mean      2.658584   552.530408    28.678575    28.609405    28.675860
# std       4.021363   330.794236     3.943793     3.947781     3.874746
# min       0.000000    40.271744    16.909994    16.909994    17.863685
# 25%       0.024447   211.769856    26.043762    25.939181    26.064920
# 50%       0.628331   590.062714    29.649118    29.571434    29.755682
# 75%       3.853519   859.759258    31.502815    31.449186    31.393429
# max      26.368990  1120.758299    35.947914    35.947914    35.410259
#
#          Tavgt-220            H
# count  7586.000000  7586.000000
# mean     28.618282   255.202328
# std       1.685025   143.615109
# min      25.611789     0.000000
# 25%      27.122418   113.000000
# 50%      28.390745   304.425000
# 75%      30.238243   350.143462
# max      31.572935   682.000000

# %%
# get datetime statistics
df_copy.date.describe()
# Out:
# <ipython-input-9-230b203a077f>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_copy.date.describe()
# count                    7586
# unique                   7586
# top       2000-12-24 00:00:00
# freq                        1
# first     2000-12-24 00:00:00
# last      2021-09-30 00:00:00
# Name: date, dtype: object

# %%
# Define a function to prepare multivariate data
# so that it is suitable for a time series.
def custom_ts_multi_data_prep(dataset, target, start, end, window, horizon):
    X = []
    y = []
    start = start + window
    if end is None:
        end = len(dataset) - horizon
    for i in range(start, end):
        indicex = range(i-window, i)
        X.append(dataset[indicex])
        indicey = range(i-1, i-1+horizon)
        y.append(target[indicey])
    return np.array(X), np.array(y)

# %%
# set date as index
df_copy.set_index("date", inplace=True)
df_copy
# Out:
#                 Pt-59      Rt-207         Tt     Tt-129    Tavgt-6  Tavgt-220  \
# date
# 2000-12-24   0.024893  806.227441  22.162928  28.957788  22.065407  28.769083
# 2000-12-25   0.024559  804.305827  22.137035  28.277483  22.060858  28.714231
# 2000-12-26   0.082533  804.002595  22.514109  27.742418  22.142795  28.662624
# 2000-12-27   0.180188  797.916736  22.487470  28.105324  22.226715  28.612342
# 2000-12-28   0.085362  785.459225  22.716461  29.599943  22.318781  28.564346
# ...               ...         ...        ...        ...        ...        ...
# 2021-09-26   9.375081  852.617897  31.067743  34.296530  30.655116  31.219590
# 2021-09-27   8.460711  853.379331  30.464815  34.135807  30.533431  31.252320
# 2021-09-28  12.678004  853.541427  30.405666  34.440166  30.548318  31.282351
# 2021-09-29   6.628835  857.843422  30.473732  34.654995  30.650742  31.310892
# 2021-09-30   7.453531  863.134363  29.751686  34.584763  30.500594  31.335883
#
#                  H
# date
# 2000-12-24  331.75
# 2000-12-25  332.74
# 2000-12-26  333.00
# 2000-12-27  333.49
# 2000-12-28  334.00
# ...            ...
# 2021-09-26  438.00
# 2021-09-27  435.00
# 2021-09-28  430.00
# 2021-09-29  425.00
# 2021-09-30  421.00
#
# [7586 rows x 7 columns]

# %%
# drop unwanted dates data
df_copy.drop(df_copy.loc['2000-12-24':'2000-12-31'].index,inplace=True) 
df_copy
# Out:
#                 Pt-59      Rt-207         Tt     Tt-129    Tavgt-6  Tavgt-220  \
# date
# 2001-01-01   0.041924  761.208178  21.818512  29.539700  22.192944  28.360960
# 2001-01-02   0.433780  760.571192  21.694710  29.886585  22.060817  28.310038
# 2001-01-03   0.026396  758.075647  21.706347  29.683380  21.892465  28.257549
# 2001-01-04   0.677911  749.605216  21.556520  30.388618  21.768334  28.204746
# 2001-01-05   0.067499  746.766451  21.191872  30.492870  21.615154  28.146621
# ...               ...         ...        ...        ...        ...        ...
# 2021-09-26   9.375081  852.617897  31.067743  34.296530  30.655116  31.219590
# 2021-09-27   8.460711  853.379331  30.464815  34.135807  30.533431  31.252320
# 2021-09-28  12.678004  853.541427  30.405666  34.440166  30.548318  31.282351
# 2021-09-29   6.628835  857.843422  30.473732  34.654995  30.650742  31.310892
# 2021-09-30   7.453531  863.134363  29.751686  34.584763  30.500594  31.335883
#
#                  H
# date
# 2001-01-01  335.00
# 2001-01-02  335.55
# 2001-01-03  336.00
# 2001-01-04  336.53
# 2001-01-05  337.00
# ...            ...
# 2021-09-26  438.00
# 2021-09-27  435.00
# 2021-09-28  430.00
# 2021-09-29  425.00
# 2021-09-30  421.00
#
# [7578 rows x 7 columns]

# %%
# split data 70 : 15 : 15 (train, val, test)
# size = int(len(df_copy)*0.8)
size = int(len(df_copy)*0.85)

df_train_val = df_copy.iloc[:size]
df_test = df_copy.iloc[size:]

print(df_train_val.head())
print(df_test.head())
print(len(df_train_val))
print(len(df_test))
# Out:
#                Pt-59      Rt-207         Tt     Tt-129    Tavgt-6  Tavgt-220  \
# date
# 2001-01-01  0.041924  761.208178  21.818512  29.539700  22.192944  28.360960
# 2001-01-02  0.433780  760.571192  21.694710  29.886585  22.060817  28.310038
# 2001-01-03  0.026396  758.075647  21.706347  29.683380  21.892465  28.257549
# 2001-01-04  0.677911  749.605216  21.556520  30.388618  21.768334  28.204746
# 2001-01-05  0.067499  746.766451  21.191872  30.492870  21.615154  28.146621
#
#                  H
# date
# 2001-01-01  335.00
# 2001-01-02  335.55
# 2001-01-03  336.00
# 2001-01-04  336.53
# 2001-01-05  337.00
#                 Pt-59      Rt-207         Tt     Tt-129    Tavgt-6  Tavgt-220  \
# date
# 2018-08-21  10.467996  679.149189  29.750473  30.904110  29.241839  29.987066
# 2018-08-22  11.963393  687.543541  29.856080  30.425873  29.217729  30.028776
# 2018-08-23   2.213231  694.136883  30.085066  30.685621  29.439231  30.071356
# 2018-08-24   1.432609  709.072926  30.803417  31.330110  29.945444  30.112409
# 2018-08-25  11.263357  731.891855  28.574038  31.833128  29.875158  30.139469
#
#                 H
# date
# 2018-08-21  449.0
# 2018-08-22  460.0
# 2018-08-23  467.0
# 2018-08-24  478.0
# 2018-08-25  507.0
# 6441
# 1137

# %%
# Display Pipeline
set_config(display='diagram')

# %%
#1st Quantile Transformer
trf1 = ColumnTransformer([
        ('quantile',QuantileTransformer(output_distribution='normal'),slice(0,6))
    ],remainder='passthrough')

#2nd Standar Scaling
trf2 = ColumnTransformer([
    ('scaler', MinMaxScaler(feature_range=(0,1)),slice(0,6))
    ],remainder='passthrough')

# %%
pipe = Pipeline([('trf1', trf1),('trf2', trf2)])

# %%
#fit data
pipe.fit(df_train_val.iloc[:,:-1])
# Out:
# Pipeline(steps=[('trf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('quantile',
#                                                   QuantileTransformer(output_distribution='normal'),
#                                                   slice(0, 6, None))])),
#                 ('trf2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('scaler', MinMaxScaler(),
#                                                   slice(0, 6, None))]))])

# %%
# apply transform to train dataset
dataX = pipe.transform(df_train_val.iloc[:,:-1])
print(dataX[0])
print(dataX.shape)
# Out:
# [0.44426671 0.5351566  0.36642021 0.5000454  0.37215046 0.50172113]
# (6441, 6)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaler.fit(df_train_val[['H']])
# Out:
# MinMaxScaler()

# %%
# Let’s standardize data
dataY = scaler.transform(df_train_val[['H']])
dataY[0]
# Out:
# array([0.5394525])

# %%
# let’s allow the model to see / train on the past 90 days of data 
# and try to forecast the next 1 day of results. Hence, use horizon = 1
# This is called Single step Forecast
hist_window = 90
horizon = 1
TRAIN_SPLIT = len(df_train_val) - len(df_test)  
x_train_multi, y_train_multi = custom_ts_multi_data_prep(
    dataX, dataY, 0, TRAIN_SPLIT, hist_window, horizon)
x_val_multi, y_val_multi= custom_ts_multi_data_prep(
    dataX, dataY, TRAIN_SPLIT, None, hist_window, horizon)
print ('Single window of past history')
print(x_train_multi[0])
print ('\n Target horizon')
print (y_train_multi[0])
print(len(x_train_multi))
print(x_train_multi.shape)
print(x_val_multi.shape)
# Out:
# Single window of past history
# [[0.44426671 0.5351566  0.36642021 0.5000454  0.37215046 0.50172113]
#  [0.49190603 0.53488632 0.3626757  0.51090335 0.3693557  0.49989922]
#  [0.43569992 0.53438278 0.36318891 0.5042368  0.36500698 0.49793815]
#  [0.50325734 0.53257956 0.35956753 0.52911406 0.36147639 0.49592568]
#  [0.45352906 0.53193429 0.35049433 0.53328471 0.35741632 0.49369687]
#  [0.39729897 0.53117394 0.34393082 0.5327434  0.35356018 0.49166653]
#  [0.48182425 0.53043462 0.35282508 0.52449784 0.35099648 0.48970798]
#  [0.49863096 0.53001535 0.35954492 0.52572386 0.35035224 0.48739532]
#  [0.53316232 0.52949042 0.36344097 0.56997514 0.35039541 0.48525522]
#  [0.50915256 0.52800276 0.37144778 0.57388447 0.3527215  0.48313519]
#  [0.48371391 0.52694748 0.37148097 0.53963207 0.35704494 0.48136051]
#  [0.48930215 0.52655808 0.36982093 0.5254508  0.36174857 0.47960174]
#  [0.47402089 0.52575973 0.37308855 0.51734727 0.36579447 0.47785312]
#  [0.4466818  0.52456133 0.3649353  0.52102943 0.36671198 0.47599968]
#  [0.48503491 0.52354468 0.36107832 0.5288844  0.36638098 0.47373755]
#  [0.44403388 0.52252921 0.37680736 0.51489686 0.36750147 0.47135462]
#  [0.454256   0.52226805 0.38256382 0.52550658 0.37004708 0.46905646]
#  [0.38274609 0.52141741 0.38001205 0.54321657 0.3714971  0.46690562]
#  [0.41706389 0.52075721 0.36383587 0.49426728 0.37037935 0.46446946]
#  [0.46554665 0.52049533 0.35746034 0.50721522 0.36868655 0.46090486]
#  [0.4488367  0.52031033 0.35290213 0.49392458 0.36738019 0.45789248]
#  [0.42422573 0.51979128 0.33738875 0.50677513 0.36022598 0.45443971]
#  [0.42135351 0.51874218 0.31492355 0.49668657 0.3484982  0.45154311]
#  [0.43400327 0.51807143 0.30730973 0.48174747 0.33602024 0.44853002]
#  [0.31450787 0.51778822 0.30847635 0.50995445 0.32554042 0.44376411]
#  [0.22622553 0.5173479  0.31360156 0.50238559 0.31753975 0.43817683]
#  [0.4098964  0.51562937 0.32675553 0.49553907 0.3133897  0.43490224]
#  [0.46204444 0.513891   0.34465696 0.51983854 0.3147023  0.43102481]
#  [0.48201372 0.51308303 0.3569195  0.54400959 0.32168886 0.42737627]
#  [0.44027392 0.51199268 0.37734664 0.50127595 0.33584672 0.42352885]
#  [0.35742143 0.51183651 0.3898889  0.47943433 0.35054413 0.42002613]
#  [0.43424408 0.51000663 0.38994768 0.49609973 0.36447498 0.41711815]
#  [0.4445016  0.50841305 0.38394625 0.52973783 0.37302988 0.41355285]
#  [0.46761384 0.50754815 0.37475787 0.52823325 0.37741306 0.4081832 ]
#  [0.42408406 0.50591632 0.35678602 0.49079997 0.37737733 0.40277953]
#  [0.42004987 0.50496535 0.3504783  0.5051215  0.37362368 0.39718121]
#  [0.40283907 0.50280834 0.35835877 0.51724515 0.3680948  0.3915304 ]
#  [0.3852701  0.50205798 0.36197487 0.50388456 0.36173771 0.38787181]
#  [0.39390688 0.50057051 0.36283239 0.51733122 0.35728911 0.38389748]
#  [0.43703062 0.49776455 0.37052086 0.52573863 0.35650995 0.38028297]
#  [0.44767816 0.49641533 0.37623723 0.50474756 0.36043618 0.37772758]
#  [0.44386116 0.49525959 0.36275388 0.50329827 0.36286336 0.37418097]
#  [0.42304361 0.49391339 0.32160908 0.50966725 0.35735571 0.3676505 ]
#  [0.3552118  0.49215513 0.27086942 0.53933547 0.34437502 0.36031065]
#  [0.35592089 0.49116249 0.25677146 0.54440747 0.32797428 0.35258391]
#  [0.35168082 0.48979057 0.29155109 0.51326269 0.31438166 0.34375519]
#  [0.34474418 0.48741694 0.3399549  0.49246526 0.29889564 0.33405502]
#  [0.38790365 0.48622175 0.36855863 0.50680289 0.30218477 0.33020657]
#  [0.34723082 0.48542299 0.38880081 0.5285351  0.32191974 0.32749694]
#  [0.2978678  0.4851167  0.39998611 0.5240926  0.34767321 0.3245193 ]
#  [0.35290689 0.48292642 0.41244633 0.51850556 0.37272577 0.3219192 ]
#  [0.33797188 0.48065853 0.41947863 0.49604089 0.39216914 0.31927518]
#  [0.3648436  0.47799166 0.42008271 0.50695602 0.40297148 0.31710598]
#  [0.38298493 0.47746851 0.41566513 0.52725639 0.40987736 0.31552951]
#  [0.36271846 0.47724192 0.42205381 0.51866608 0.41540439 0.31399342]
#  [0.38593039 0.47343668 0.43565588 0.49146498 0.4222382  0.31248565]
#  [0.28529802 0.47085224 0.45036162 0.46645803 0.42837104 0.3115468 ]
#  [0.37496449 0.47045629 0.45441664 0.46278458 0.43302587 0.31069092]
#  [0.29957313 0.46906976 0.43138482 0.47205114 0.43503912 0.30944474]
#  [0.35378897 0.4681596  0.42965236 0.48278453 0.43766436 0.30813286]
#  [0.40460215 0.46670478 0.44593375 0.47911324 0.44204133 0.30744731]
#  [0.45502716 0.46636419 0.4578255  0.47182149 0.44603152 0.30698036]
#  [0.41169116 0.46390914 0.46799276 0.47219466 0.44838386 0.30577502]
#  [0.41201988 0.46273201 0.47142063 0.46345632 0.45077997 0.30459922]
#  [0.40228823 0.46127873 0.45858177 0.45495581 0.45480076 0.30443311]
#  [0.38966788 0.46062518 0.44498231 0.44914921 0.45686371 0.30469242]
#  [0.37769341 0.45805413 0.44011612 0.44890885 0.45601368 0.30365644]
#  [0.40324775 0.45698464 0.44758847 0.44928612 0.45475001 0.30055703]
#  [0.41127557 0.45482174 0.45323415 0.4529716  0.45306227 0.29802374]
#  [0.27646329 0.45211295 0.45778981 0.45457172 0.45102709 0.29751825]
#  [0.35053214 0.45103454 0.45951873 0.45884855 0.45118254 0.29479534]
#  [0.32064523 0.44857908 0.46511323 0.46329102 0.45402814 0.29292576]
#  [0.21856929 0.44663134 0.46638114 0.45800933 0.45771243 0.29161662]
#  [0.37967515 0.44518568 0.47002279 0.44409515 0.46068527 0.29074585]
#  [0.38134023 0.44431643 0.46412848 0.43614383 0.46235892 0.28961217]
#  [0.27981411 0.44354223 0.47034565 0.4363053  0.4643751  0.28847332]
#  [0.31514328 0.44173911 0.47791867 0.44056231 0.4667915  0.28911111]
#  [0.24228349 0.43995903 0.48266081 0.44344738 0.46908675 0.28837842]
#  [0.29381239 0.43882519 0.48867627 0.4424645  0.47247781 0.28635122]
#  [0.25510418 0.43763591 0.49576274 0.43374362 0.47552122 0.28563302]
#  [0.32516011 0.43625645 0.49531059 0.43409833 0.48075098 0.28567532]
#  [0.36015059 0.43564808 0.48826735 0.43134796 0.48421333 0.28540228]
#  [0.2345274  0.43354942 0.48933761 0.43312477 0.48607941 0.28591159]
#  [0.25378311 0.43214401 0.49020863 0.4386613  0.48795012 0.28671005]
#  [0.2813441  0.43007484 0.50178304 0.4356212  0.49044063 0.28930144]
#  [0.31313405 0.42962633 0.51757533 0.42923362 0.49435664 0.29176914]
#  [0.28293557 0.42929819 0.5316095  0.42949132 0.49988973 0.29492629]
#  [0.31223612 0.42869483 0.5367274  0.43588385 0.50840928 0.29833468]
#  [0.31558917 0.42734423 0.53453654 0.4333102  0.51731995 0.29947982]
#  [0.39659159 0.42559557 0.52217838 0.43642384 0.52451425 0.30065248]]
#
#  Target horizon
# [[0.20869565]]
# 5214
# (5214, 90, 6)
# (1046, 90, 6)

# %%
# reshape input feature for ConvLSTM 
x_train_multi_ConvLSTM = x_train_multi.reshape((x_train_multi.shape[0], 2, 1,
x_train_multi.shape[1]//2, x_train_multi.shape[2]))
print(x_train_multi_ConvLSTM.shape)

x_val_multi_ConvLSTM = x_val_multi.reshape((x_val_multi.shape[0], 2, 1,
x_val_multi.shape[1]//2, x_val_multi.shape[2]))
print(x_val_multi_ConvLSTM.shape)
# Out:
# (5214, 2, 1, 45, 6)
# (1046, 2, 1, 45, 6)

# %%
# Prepare CovLSTM2D training and validation time-series data
BATCH_SIZE = 256
BUFFER_SIZE = 150
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi_ConvLSTM, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi_ConvLSTM, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
# Define the ConvLSTM model

ConvLSTM_model = Sequential()
ConvLSTM_model.add(ConvLSTM2D(filters=64, kernel_size=(1,3), activation='tanh', 
input_shape=(2, 1, x_train_multi_ConvLSTM.shape[3], x_train_multi_ConvLSTM.shape[4])))
ConvLSTM_model.add(Dropout(0.2))
ConvLSTM_model.add(Flatten())
ConvLSTM_model.add(Dense(30, activation='swish'))
ConvLSTM_model.add(Dropout(0.2))
ConvLSTM_model.add(Dense(horizon))
ConvLSTM_model.compile(optimizer='adam', loss='mse')

# %%
# the best weights are stored in model path
model_path = r'/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/ConvLSTM_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax.h5'

# %%
# Configure the model and start training with early stopping and checkpointing

EVALUATION_INTERVAL = 150
EPOCHS = 500
history = ConvLSTM_model.fit(train_data_multi, epochs=EPOCHS,
steps_per_epoch=EVALUATION_INTERVAL,validation_data=val_data_multi,
validation_steps=50,verbose =1,callbacks =[tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='min'),
    tf.keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', 
    save_best_only=True, mode='min', verbose=0)])
# Out:
# Epoch 1/500
# 150/150 [==============================] - 11s 35ms/step - loss: 0.0391 - val_loss: 0.0162
# Epoch 2/500
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0133 - val_loss: 0.0094
# Epoch 3/500
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0110 - val_loss: 0.0085
# Epoch 4/500
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0102 - val_loss: 0.0118
# Epoch 5/500
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0103 - val_loss: 0.0088
# Epoch 6/500
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0094 - val_loss: 0.0103
# Epoch 7/500
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0089 - val_loss: 0.0145
# Epoch 8/500
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0091 - val_loss: 0.0159
# Epoch 9/500
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0088 - val_loss: 0.0100
# Epoch 10/500
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0082 - val_loss: 0.0088
# Epoch 11/500
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0080 - val_loss: 0.0106
# Epoch 12/500
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0082 - val_loss: 0.0095
# Epoch 13/500
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0078 - val_loss: 0.0100
# Epoch 00013: early stopping

# %%
# Load the best weights into the model
Trained_model = tf.keras.models.load_model(model_path)

# %%
# Plot the loss and val_loss against the epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'],color='red')
plt.title('Model loss',size=14,fontweight='bold')
plt.ylabel('Loss',size=12,fontweight='semibold')
plt.xlabel('Epoch',size=12,fontweight='semibold')
plt.legend(['Train loss', 'Validation loss'])
plt.figure(figsize=(16,9))
plt.show()

# %%
# Check the model summary
Trained_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d (ConvLSTM2D)    (None, 1, 43, 64)         54016
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 43, 64)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2752)              0
# _________________________________________________________________
# dense (Dense)                (None, 30)                82590
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 136,637
# Trainable params: 136,637
# Non-trainable params: 0
# _________________________________________________________________

# %%
# assign the number of days to validate model
val_period = len(df_test) - hist_window - horizon
val_period
# Out:
# 1046

# %%
# hold back 5 years data from test DataFrame to be used for testing the model
# validate DataFrame
validate = df_test.iloc[:,:].tail(val_period)

# %%
# apply transform to test dataset
validateX = pipe.transform(df_test.iloc[:,:-1])

print(validateX[0])
print(validateX.shape)
# Out:
# [0.64915934 0.51788998 0.50394085 0.54875995 0.48451139 0.55653959]
# (1137, 6)

# %%
# Let’s standardize data
validateY = scaler.transform(df_test[['H']])
validateY[0]
# Out:
# array([0.72302738])

# %%
# Prepare test dataset
x_test_multi, y_test_multi = custom_ts_multi_data_prep(
    validateX, validateY, 0, None, hist_window, horizon)
print ('Single window of past history')
print(x_test_multi[0])
print ('\n Target horizon')
print (y_test_multi[0])
print(x_test_multi.shape)
# Out:
# Single window of past history
# [[0.64915934 0.51788998 0.50394085 0.54875995 0.48451139 0.55653959]
#  [0.66851684 0.51928518 0.50724615 0.53032186 0.48381069 0.55811863]
#  [0.54069849 0.52059811 0.51472431 0.54105049 0.49073204 0.55994025]
#  [0.52520375 0.52401377 0.54135239 0.56337311 0.50812177 0.56186623]
#  [0.66006713 0.52893511 0.47215419 0.58106726 0.50600073 0.5630003 ]
#  [0.61980647 0.53002511 0.46396184 0.58793935 0.49413503 0.56430323]
#  [0.54690516 0.53147397 0.46821193 0.59788748 0.4860022  0.56561089]
#  [0.61902648 0.53397592 0.48774495 0.59145644 0.48348732 0.5669316 ]
#  [0.67112889 0.53601291 0.50781313 0.61116535 0.48241117 0.56889276]
#  [0.68589755 0.53896876 0.4921757  0.63706688 0.4765243  0.57056298]
#  [0.56129766 0.54245054 0.46668908 0.6586765  0.47573379 0.57210809]
#  [0.56728687 0.54405029 0.46664991 0.68718521 0.47622433 0.57377269]
#  [0.6279826  0.54618582 0.48326568 0.6400578  0.47883479 0.57541952]
#  [0.69510202 0.54890682 0.47983288 0.66274938 0.47749432 0.57757889]
#  [0.55532396 0.55204648 0.49452259 0.63878804 0.4761236  0.57976763]
#  [0.67412849 0.55600653 0.51953884 0.6730877  0.47924914 0.58169482]
#  [0.58032815 0.55907807 0.50989923 0.69084054 0.48659457 0.58329341]
#  [0.57130456 0.56428773 0.4980638  0.69530802 0.49404529 0.58517274]
#  [0.57839014 0.57028523 0.47687952 0.64342723 0.49247268 0.58687371]
#  [0.63571295 0.57765844 0.46164008 0.6036405  0.4866928  0.58831042]
#  [0.55173465 0.58420085 0.46408805 0.60183037 0.48072358 0.58992727]
#  [0.55780681 0.58888451 0.46792518 0.59711737 0.47421401 0.59129322]
#  [0.70483986 0.59107442 0.51070297 0.58742963 0.47426649 0.59289826]
#  [0.62151654 0.59412013 0.53588486 0.62353826 0.47763443 0.59394873]
#  [0.62601151 0.60146472 0.50034403 0.67631287 0.48126954 0.59492966]
#  [0.61528415 0.60465402 0.49515135 0.6676339  0.48832725 0.59597146]
#  [0.57990737 0.60770317 0.50284464 0.62045687 0.4976558  0.59727229]
#  [0.67547211 0.6085577  0.52255745 0.61884941 0.50869681 0.59953491]
#  [0.58712816 0.60957509 0.55627722 0.61774979 0.51724431 0.60381231]
#  [0.55225465 0.61083837 0.55107509 0.64996589 0.51988692 0.60781009]
#  [0.52594773 0.61394977 0.55560827 0.70687168 0.53216134 0.61355792]
#  [0.66283547 0.61709787 0.55383039 0.66166069 0.54355102 0.61863243]
#  [0.72031863 0.6239795  0.51910348 0.6584848  0.54695411 0.62235476]
#  [0.58143936 0.62736774 0.53426865 0.63055997 0.54925311 0.62548166]
#  [0.59834375 0.6364679  0.5548824  0.6318296  0.54895604 0.62794657]
#  [0.58707765 0.63905912 0.54470415 0.7175049  0.54765525 0.63080934]
#  [0.59412293 0.63962692 0.55250803 0.78540487 0.54707957 0.63386023]
#  [0.63772876 0.64141847 0.54895718 0.73485033 0.54590475 0.63647394]
#  [0.60577411 0.64360146 0.53403673 0.7375977  0.54915015 0.63790182]
#  [0.64697514 0.64588551 0.51991038 0.74843564 0.54608377 0.63939684]
#  [0.67204983 0.64769538 0.53589334 0.75751097 0.54287532 0.64153691]
#  [0.68768061 0.6504107  0.53534062 0.72607564 0.54120725 0.64304374]
#  [0.63411419 0.65125517 0.54343039 0.67040861 0.53970187 0.64518797]
#  [0.6164324  0.65304627 0.55188167 0.66406013 0.54017844 0.64688487]
#  [0.71459933 0.6569355  0.54585551 0.5928503  0.54222966 0.64850532]
#  [0.68086246 0.66225272 0.51357178 0.61664653 0.54105101 0.64902896]
#  [0.59989713 0.66309721 0.54301636 0.65323996 0.54225711 0.65076377]
#  [0.60988381 0.66346377 0.55191284 0.6456089  0.54502383 0.65179231]
#  [0.68163855 0.66364288 0.56651317 0.60178441 0.55016963 0.65272263]
#  [0.59780629 0.66377261 0.54613792 0.63913534 0.54931068 0.65283635]
#  [0.62531442 0.66517372 0.54040076 0.67443372 0.54823683 0.65285431]
#  [0.64713052 0.66526449 0.52471938 0.68166873 0.55030118 0.6530924 ]
#  [0.62927657 0.66543437 0.54905829 0.68234738 0.55090266 0.65431705]
#  [0.58610379 0.6662205  0.52928653 0.6236318  0.54715911 0.65514609]
#  [0.55287853 0.66653508 0.51967537 0.66745349 0.5384858  0.65478927]
#  [0.85867771 0.66709924 0.50793118 0.75442392 0.53034127 0.65374083]
#  [0.68677654 0.66719489 0.54708097 0.7568305  0.53186299 0.65365876]
#  [0.63220172 0.6674735  0.55882275 0.65048362 0.53873039 0.65398021]
#  [0.63064925 0.66779435 0.56012709 0.62253424 0.54089531 0.6543536 ]
#  [0.62998532 0.66864358 0.55182581 0.66107293 0.54467427 0.6548061 ]
#  [0.6243712  0.66904154 0.55124237 0.75195124 0.55059186 0.65544662]
#  [0.60284478 0.66923812 0.54934523 0.70585722 0.55713216 0.65583315]
#  [0.70907988 0.66926284 0.55105404 0.70511388 0.5576814  0.65630645]
#  [0.79560102 0.66908137 0.54697586 0.68252892 0.55555642 0.65670936]
#  [0.59297523 0.66681974 0.55022649 0.63971477 0.55382602 0.65756791]
#  [0.6020332  0.66683665 0.53004003 0.65322871 0.55054106 0.65783085]
#  [0.67483752 0.66706752 0.49765002 0.63771308 0.54028324 0.65724473]
#  [0.64114888 0.66776777 0.48903685 0.5887336  0.52756773 0.65576668]
#  [0.66939831 0.6686235  0.51053082 0.584178   0.51915331 0.65635654]
#  [0.68492647 0.67289635 0.51313517 0.56711046 0.51243977 0.65985284]
#  [0.59355798 0.67366485 0.53118458 0.53780873 0.50928302 0.66468249]
#  [0.59093064 0.67539242 0.50926515 0.50594807 0.50610029 0.66764875]
#  [0.63108983 0.67395599 0.49366423 0.54780241 0.50557645 0.6691418 ]
#  [0.60237933 0.67175114 0.48592652 0.62407175 0.50486444 0.66920223]
#  [0.63272589 0.67131014 0.47029019 0.58243471 0.49631282 0.66905911]
#  [0.63141085 0.67150293 0.47105942 0.54646709 0.48742764 0.66899186]
#  [0.6542895  0.67203171 0.47056351 0.56974899 0.4784803  0.66828483]
#  [0.66934148 0.67087412 0.47024342 0.56279308 0.4737465  0.66805643]
#  [0.66927744 0.67188876 0.47179173 0.55606435 0.47088278 0.66703552]
#  [0.70528535 0.67181576 0.46666297 0.50229308 0.46800884 0.66562465]
#  [0.61341611 0.67159537 0.46036797 0.55369327 0.46620442 0.66337366]
#  [0.55164157 0.67154043 0.45351859 0.56584115 0.46365305 0.65969437]
#  [0.56865932 0.67113119 0.44951975 0.57258687 0.46028732 0.65640698]
#  [0.60108842 0.67102449 0.44902833 0.52940967 0.45753914 0.65207006]
#  [0.57288051 0.67125955 0.45350941 0.55345978 0.45525199 0.64806235]
#  [0.58122761 0.67209027 0.45491841 0.56975822 0.45373188 0.64520328]
#  [0.54252192 0.67224635 0.44626622 0.56752349 0.4516861  0.64170552]
#  [0.54728031 0.6708036  0.43944952 0.57244386 0.44954402 0.6369877 ]
#  [0.55085063 0.67055589 0.44247301 0.57785308 0.44825917 0.63344109]
#  [0.56857369 0.67081459 0.44555357 0.57325902 0.44753629 0.63018083]]
#
#  Target horizon
# [[0.56360709]]
# (1046, 90, 6)

# %%
# reshape for ConvLSTM2D
x_test_multi_ConvLSTM = x_test_multi.reshape((x_test_multi.shape[0], 2, 1,
x_test_multi.shape[1]//2, x_test_multi.shape[2]))
print(x_test_multi_ConvLSTM.shape)
# Out:
# (1046, 2, 1, 45, 6)

# %%
# predictions for ConvLSTM2D

predictions = []
for i in x_test_multi_ConvLSTM:
    # predict the daily streamflow
    i_reshape = i.reshape(1, i.shape[0], i.shape[1], i.shape[2], i.shape[3])
    Predicted_results = Trained_model.predict(i_reshape)
    # store the predictions
    predictions.append(Predicted_results)
print(predictions[0])
# Out:
# [[0.5657158]]

# %%
# convert prediction list to numpy array
predictions = np.array(predictions).reshape(-1, 1)
print(predictions.shape)
# Out:
# (1046, 1)

# %%
# Rescale the predicted values back to the original scale.

predictions_Inv_trans = scaler.inverse_transform(predictions)
print(predictions_Inv_trans[0])
print(predictions_Inv_trans.shape)
# Out:
# [351.3095]
# (1046, 1)

# %%
# Define the time-series evaluation function

def timeseries_evaluation_metrics_func(y_true, y_pred):
    kgeprime, r, gamma, beta = he.kgeprime(y_pred, y_true)
    kge, r, alpha, beta = he.kge(y_pred, y_true)
    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'NSE is : {he.nse(np.array(y_pred), np.array(y_true))}')
    print(f"KGE' is : {kgeprime}")
    print(f'r is : {r}, gamma is : {gamma}')
    print(f'KGE is : {kge}')
    print(f'alpha is : {alpha}, beta is : {beta}')
    print(f'PBIAS is : {he.pbias(np.array(y_pred), np.array(y_true))}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MARE is : {he.mare(np.array(y_pred), np.array(y_true))}')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}') 
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')
timeseries_evaluation_metrics_func(validate['H'].values.reshape(-1, 1),predictions_Inv_trans)
# Out:
# Evaluation metric results:-
# NSE is : [0.84740578]
# KGE' is : [0.8755647]
# r is : [0.94416013], gamma is : [0.98835272]
# KGE is : [0.82685997]
# alpha is : [0.87904966], beta is : [0.88940889]
# PBIAS is : [11.05911113]
# RMSE is : 61.33834414604634
# MARE is : [0.15925333]
# MSE is : 3762.3924625788172
# MAE is : 45.106145978657736
# MAPE is : 22.637498102259524
# R2 is : 0.8474057846812815

# %%
# Plot the Observed versus predicted values.
plt.plot( list(validate['H'] / 100))
plt.plot( list(predictions_Inv_trans / 100),color='red')
plt.title("Observed vs Predicted",size=14,fontweight='bold')
plt.ylabel("Water Level (m)",size=12,fontweight='semibold')
plt.legend(('Observed','Predicted'))
plt.figure(figsize=(16,9))
plt.show()

# %%
# save GPM IMERGE train loss and val loss to CSV
df_history = pd.DataFrame.from_records([history.history['loss'],history.history['val_loss']], index=['train_loss', 'val_loss']).transpose()
df_history.to_csv('/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/ConvLSTM_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax_history.csv', index=False)

# %%
# Hybrid CNN LSTM

# import all libraries and modules
import tensorflow as tf # deep learning api
import pandas as pd  # for data manipulation
import numpy as np    # for mathematical calculation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten,TimeDistributed,RepeatVector
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import MaxPool1D
from tensorflow.keras.layers import Dropout
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.preprocessing import QuantileTransformer, StandardScaler, MinMaxScaler
tf.random.set_seed(123)
np.random.seed(123)
import datetime
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import set_config
import hydroeval as he

# %%
# reshape input feature for Hybrid CNN LSTM 
x_train_multi_CNN_LSTM = x_train_multi.reshape((x_train_multi.shape[0], 2, 
x_train_multi.shape[1]//2, x_train_multi.shape[2]))
print(x_train_multi_CNN_LSTM.shape)

x_val_multi_CNN_LSTM = x_val_multi.reshape((x_val_multi.shape[0], 2, 
x_val_multi.shape[1]//2, x_val_multi.shape[2]))
print(x_val_multi_CNN_LSTM.shape)
# Out:
# (5214, 2, 45, 6)
# (1046, 2, 45, 6)

# %%
# Prepare  CNN LSTM training and validation time-series data
BATCH_SIZE = 256
BUFFER_SIZE = 150
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi_CNN_LSTM, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi_CNN_LSTM, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
# Define the CNN LSTM model

CNN_LSTM_model = Sequential()
CNN_LSTM_model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='swish',
input_shape=(None, x_train_multi_CNN_LSTM.shape[2], x_train_multi_CNN_LSTM.shape[3]))))
CNN_LSTM_model.add(TimeDistributed(MaxPool1D(pool_size=2)))
CNN_LSTM_model.add(TimeDistributed(Dropout(0.2)))
CNN_LSTM_model.add(TimeDistributed(Flatten()))
CNN_LSTM_model.add(LSTM(units=100,activation='tanh'))
CNN_LSTM_model.add(Dropout(0.2))
CNN_LSTM_model.add(Dense(horizon))
CNN_LSTM_model.compile(optimizer='adam', loss='mse')

# %%
# the best weights are stored in model path
model_path = r'/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/CNN_LSTM_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax.h5'

# %%
# Configure the model and start training with early stopping and checkpointing

EVALUATION_INTERVAL = 150
EPOCHS = 500
history = CNN_LSTM_model.fit(train_data_multi, epochs=EPOCHS,
steps_per_epoch=EVALUATION_INTERVAL,validation_data=val_data_multi,
validation_steps=50,verbose =1,callbacks =[tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='min'),
    tf.keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', 
    save_best_only=True, mode='min', verbose=0)])
# Out:
# Epoch 1/500
# 150/150 [==============================] - 5s 17ms/step - loss: 0.0422 - val_loss: 0.0140
# Epoch 2/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0101 - val_loss: 0.0080
# Epoch 3/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0084 - val_loss: 0.0064
# Epoch 4/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0080 - val_loss: 0.0077
# Epoch 5/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0077 - val_loss: 0.0069
# Epoch 6/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0070 - val_loss: 0.0083
# Epoch 7/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0064 - val_loss: 0.0113
# Epoch 8/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0062 - val_loss: 0.0098
# Epoch 9/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0060 - val_loss: 0.0068
# Epoch 10/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0055 - val_loss: 0.0064
# Epoch 11/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0054 - val_loss: 0.0092
# Epoch 12/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0054 - val_loss: 0.0082
# Epoch 13/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0051 - val_loss: 0.0087
# Epoch 14/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0048 - val_loss: 0.0100
# Epoch 15/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0048 - val_loss: 0.0089
# Epoch 16/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0050 - val_loss: 0.0065
# Epoch 17/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0044 - val_loss: 0.0062
# Epoch 18/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0042 - val_loss: 0.0085
# Epoch 19/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0042 - val_loss: 0.0078
# Epoch 20/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0041 - val_loss: 0.0085
# Epoch 21/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0039 - val_loss: 0.0094
# Epoch 22/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0038 - val_loss: 0.0082
# Epoch 23/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0038 - val_loss: 0.0062
# Epoch 24/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0034 - val_loss: 0.0066
# Epoch 25/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0034 - val_loss: 0.0089
# Epoch 26/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0036 - val_loss: 0.0074
# Epoch 27/500
# 150/150 [==============================] - 1s 7ms/step - loss: 0.0033 - val_loss: 0.0088
# Epoch 00027: early stopping

# %%
# Load the best weights into the model
Trained_model = tf.keras.models.load_model(model_path)

# %%
# Plot the loss and val_loss against the epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'],color='red')
plt.title('Model loss',size=14,fontweight='bold')
plt.ylabel('Loss',size=12,fontweight='semibold')
plt.xlabel('Epoch',size=12,fontweight='semibold')
plt.legend(['Train loss', 'Validation loss'])
plt.figure(figsize=(16,9))
plt.show()

# %%
# Check the model summary
Trained_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 2, 43, 64)         1216
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 2, 21, 64)         0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 2, 21, 64)         0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 2, 1344)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               578000
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 579,317
# Trainable params: 579,317
# Non-trainable params: 0
# _________________________________________________________________

# %%
# reshape for Hybrid CNN LSTM
x_test_multi_CNN_LSTM = x_test_multi.reshape((x_test_multi.shape[0], 2, 
x_test_multi.shape[1]//2, x_test_multi.shape[2]))
print(x_test_multi_CNN_LSTM.shape)
print(len(x_test_multi_CNN_LSTM))
# Out:
# (1046, 2, 45, 6)
# 1046

# %%
# predictions for hybrid CNN LSTM

predictions = []
for i in x_test_multi_CNN_LSTM:
    # predict the daily streamflow
    i_reshape = i.reshape(1, i.shape[0], i.shape[1], i.shape[2])
    Predicted_results = Trained_model.predict(i_reshape)
    # store the predictions
    predictions.append(Predicted_results)
print(predictions[0])
# Out:
# [[0.5182883]]

# %%
# convert prediction list to numpy array
predictions = np.array(predictions).reshape(-1, 1)
print(predictions.shape)
# Out:
# (1046, 1)

# %%
# Rescale the predicted values back to the original scale.

predictions_Inv_trans = scaler.inverse_transform(predictions)
print(predictions_Inv_trans[0])
print(predictions_Inv_trans.shape)
# Out:
# [321.85706]
# (1046, 1)

# %%
# correct evaluation metrics

# Define the time-series evaluation function

def timeseries_evaluation_metrics_func(y_true, y_pred):
    kgeprime, r, gamma, beta = he.kgeprime(y_pred, y_true)
    kge, r, alpha, beta = he.kge(y_pred, y_true)
    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'NSE is : {he.nse(np.array(y_pred), np.array(y_true))}')
    print(f"KGE' is : {kgeprime}")
    print(f'r is : {r}, gamma is : {gamma}')
    print(f'KGE is : {kge}')
    print(f'alpha is : {alpha}, beta is : {beta}')
    print(f'PBIAS is : {he.pbias(np.array(y_pred), np.array(y_true))}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MARE is : {he.mare(np.array(y_pred), np.array(y_true))}')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}') 
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')
timeseries_evaluation_metrics_func(validate['H'].values.reshape(-1, 1),predictions_Inv_trans)
# Out:
# Evaluation metric results:-
# NSE is : [0.89498145]
# KGE' is : [0.93344978]
# r is : [0.94923765], gamma is : [0.99909654]
# KGE is : [0.92028449]
# alpha is : [0.95610869], beta is : [0.95697327]
# PBIAS is : [4.3026728]
# RMSE is : 50.88573032490889
# MARE is : [0.13285274]
# MSE is : 2589.357550699352
# MAE is : 37.62857034511821
# MAPE is : 19.60267010785533
# R2 is : 0.8949814546040891

# %%
# Plot the Observed versus predicted values.
plt.plot( list(validate['H'] / 100))
plt.plot( list(predictions_Inv_trans / 100),color='red')
plt.title("Observed vs Predicted",size=14,fontweight='bold',family='serif')
plt.ylabel("Water Level (m)",size=12,fontweight='semibold',family='serif')
plt.legend(('Observed','Predicted'))  # plt.legend(('Observed','predicted'), loc=' upper left ')
plt.figure(figsize=(16,9))
plt.show()

# %%
# save GPM IMERGE train loss and val loss to CSV
df_history = pd.DataFrame.from_records([history.history['loss'],history.history['val_loss']], index=['train_loss', 'val_loss']).transpose()
df_history.to_csv('/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/CNN_LSTM_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax_history.csv', index=False)

# %%
# Hybrid CNN GRU

# import all libraries and modules
import tensorflow as tf # deep learning api
import pandas as pd  # for data manipulation
import numpy as np    # for mathematical calculation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten,TimeDistributed,RepeatVector
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import MaxPool1D
from tensorflow.keras.layers import Dropout
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.preprocessing import QuantileTransformer, StandardScaler, MinMaxScaler
tf.random.set_seed(123)
np.random.seed(123)
import datetime
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import set_config
import hydroeval as he

# %%
# tensorflow version
tf.__version__
# Out:
# '2.4.1'

# %%
# reshape input feature for Hybrid CNN GRU 
x_train_multi_CNN_GRU = x_train_multi.reshape((x_train_multi.shape[0], 2, 
x_train_multi.shape[1]//2, x_train_multi.shape[2]))
print(x_train_multi_CNN_GRU.shape)

x_val_multi_CNN_GRU = x_val_multi.reshape((x_val_multi.shape[0], 2, 
x_val_multi.shape[1]//2, x_val_multi.shape[2]))
print(x_val_multi_CNN_GRU.shape)
print(len(x_val_multi_CNN_GRU))
# Out:
# (5214, 2, 45, 6)
# (1046, 2, 45, 6)
# 1046

# %%
# Prepare  CNN GRU training and validation time-series data
BATCH_SIZE = 256
BUFFER_SIZE = 150
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi_CNN_GRU, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi_CNN_GRU, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
# Define the CNN GRU model

CNN_GRU_model = Sequential()
CNN_GRU_model.add(TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='swish',
input_shape=(None, x_train_multi_CNN_GRU.shape[2], x_train_multi_CNN_GRU.shape[3]))))
CNN_GRU_model.add(TimeDistributed(MaxPool1D(pool_size=2)))
CNN_GRU_model.add(TimeDistributed(Dropout(0.2)))
CNN_GRU_model.add(TimeDistributed(Flatten()))
CNN_GRU_model.add(GRU(units=100,activation='tanh'))
CNN_GRU_model.add(Dropout(0.2))
CNN_GRU_model.add(Dense(horizon))
CNN_GRU_model.compile(optimizer='adam', loss='mse')

# %%
# the best weights are stored in model path
model_path = r'/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/CNN_GRU_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax.h5'

# %%
# Configure the model and start training with early stopping and checkpointing

EVALUATION_INTERVAL = 150
EPOCHS = 500
history = CNN_GRU_model.fit(train_data_multi, epochs=EPOCHS,
steps_per_epoch=EVALUATION_INTERVAL,validation_data=val_data_multi,
validation_steps=50,verbose =1,callbacks =[tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='min'),
    tf.keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', 
    save_best_only=True, mode='min', verbose=0)])
# Out:
# Epoch 1/500
# 150/150 [==============================] - 3s 11ms/step - loss: 0.0655 - val_loss: 0.0163
# Epoch 2/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0117 - val_loss: 0.0085
# Epoch 3/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0096 - val_loss: 0.0067
# Epoch 4/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0092 - val_loss: 0.0080
# Epoch 5/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0088 - val_loss: 0.0074
# Epoch 6/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0080 - val_loss: 0.0096
# Epoch 7/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0076 - val_loss: 0.0137
# Epoch 8/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0075 - val_loss: 0.0126
# Epoch 9/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0073 - val_loss: 0.0082
# Epoch 10/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 11/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0062 - val_loss: 0.0069
# Epoch 12/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0058 - val_loss: 0.0074
# Epoch 13/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0056 - val_loss: 0.0090
# Epoch 14/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0051 - val_loss: 0.0104
# Epoch 15/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0052 - val_loss: 0.0092
# Epoch 16/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0051 - val_loss: 0.0076
# Epoch 17/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0047 - val_loss: 0.0066
# Epoch 18/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0046 - val_loss: 0.0106
# Epoch 19/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0046 - val_loss: 0.0114
# Epoch 20/500
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0051 - val_loss: 0.0098
# Epoch 00020: early stopping

# %%
# Load the best weights into the model
Trained_model = tf.keras.models.load_model(model_path)

# %%
# Plot the loss and val_loss against the epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'],color='red')
plt.title('Model loss',size=14,fontweight='bold')
plt.ylabel('Loss',size=12,fontweight='semibold')
plt.xlabel('Epoch',size=12,fontweight='semibold')
plt.legend(['Train loss', 'Validation loss'])
plt.figure(figsize=(16,9))
plt.show()

# %%
# Check the model summary
Trained_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_4 (TimeDist (None, 2, 43, 64)         1216
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 2, 21, 64)         0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 2, 21, 64)         0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 2, 1344)           0
# _________________________________________________________________
# gru (GRU)                    (None, 100)               433800
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 435,117
# Trainable params: 435,117
# Non-trainable params: 0
# _________________________________________________________________

# %%
# reshape for Hybrid CNN GRU
x_test_multi_CNN_GRU = x_test_multi.reshape((x_test_multi.shape[0], 2, 
x_test_multi.shape[1]//2, x_test_multi.shape[2]))
print(x_test_multi_CNN_GRU.shape)
print(len(x_test_multi_CNN_GRU))
# Out:
# (1046, 2, 45, 6)
# 1046

# %%
# predictions for hybrid CNN GRU

predictions = []
for i in x_test_multi_CNN_GRU:
    # predict the daily streamflow
    i_reshape = i.reshape(1, i.shape[0], i.shape[1], i.shape[2])
    Predicted_results = Trained_model.predict(i_reshape)
    # store the predictions
    predictions.append(Predicted_results)
print(predictions[0])
# Out:
# [[0.5189973]]

# %%
# convert prediction list to numpy array
predictions = np.array(predictions).reshape(-1, 1)
print(predictions.shape)
# Out:
# (1046, 1)

# %%
# Rescale the predicted values back to the original scale.

predictions_Inv_trans = scaler.inverse_transform(predictions)
print(predictions_Inv_trans[0])
print(predictions_Inv_trans.shape)
# Out:
# [322.29733]
# (1046, 1)

# %%
# correct evaluation metrics

# Define the time-series evaluation function

def timeseries_evaluation_metrics_func(y_true, y_pred):
    kgeprime, r, gamma, beta = he.kgeprime(y_pred, y_true)
    kge, r, alpha, beta = he.kge(y_pred, y_true)
    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'NSE is : {he.nse(np.array(y_pred), np.array(y_true))}')
    print(f"KGE' is : {kgeprime}")
    print(f'r is : {r}, gamma is : {gamma}')
    print(f'KGE is : {kge}')
    print(f'alpha is : {alpha}, beta is : {beta}')
    print(f'PBIAS is : {he.pbias(np.array(y_pred), np.array(y_true))}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MARE is : {he.mare(np.array(y_pred), np.array(y_true))}')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}') 
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')
timeseries_evaluation_metrics_func(validate['H'].values.reshape(-1, 1),predictions_Inv_trans)
# Out:
# Evaluation metric results:-
# NSE is : [0.83521314]
# KGE' is : [0.90394871]
# r is : [0.91964092], gamma is : [1.03342953]
# KGE is : [0.90954805]
# alpha is : [0.99144202], beta is : [0.95937075]
# PBIAS is : [4.06292509]
# RMSE is : 63.74179705146297
# MARE is : [0.16358131]
# MSE is : 4063.016691349893
# MAE is : 46.33198079523803
# MAPE is : 20.160228875010226
# R2 is : 0.8352131389774161

# %%
# Plot the Observed versus predicted values.
plt.plot( list(validate['H'] / 100))
plt.plot( list(predictions_Inv_trans / 100),color='red')
plt.title("Observed vs Predicted",size=14,fontweight='bold')
plt.ylabel("Water Level (m)",size=12,fontweight='semibold')
plt.legend(('Observed','Predicted'))
plt.figure(figsize=(16,9))
plt.show()

# %%
# save GPM IMERGE train loss and val loss to CSV
df_history = pd.DataFrame.from_records([history.history['loss'],history.history['val_loss']], index=['train_loss', 'val_loss']).transpose()
df_history.to_csv('/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/CNN_GRU_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax_history.csv', index=False)

# %%
# 4th Model
# Auto-encoder LSTM Model

# import all libraries and modules
import tensorflow as tf # deep learning api
import pandas as pd  # for data manipulation
import numpy as np    # for mathematical calculation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,TimeDistributed,RepeatVector
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.preprocessing import QuantileTransformer, StandardScaler, MinMaxScaler
tf.random.set_seed(123)
np.random.seed(123)
import datetime
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import set_config
import hydroeval as he

# %%
# Prepare the training and validation time-series data
BATCH_SIZE = 256
BUFFER_SIZE = 150
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
# Define the Auto-encoder LSTM model

# Define the auto-encoder LSTM model.
ED_lstm_model = Sequential([
    LSTM(40, activation='tanh',input_shape=x_train_multi.shape[-2:], 
    return_sequences=True),
    LSTM(units=20,activation='tanh',return_sequences=True),
    LSTM(units=15),
    RepeatVector(y_train_multi.shape[1]),
    LSTM(units=40,activation='tanh',return_sequences=True),
    LSTM(units=25,activation='tanh',return_sequences=True),
    TimeDistributed(tf.keras.layers.Dense(units=1))
])
ED_lstm_model.compile(optimizer='adam', loss='mse')

# %%
# the best weights are stored in model path
model_path = r'/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/ED_LSTM_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax.h5'

# %%
# Configure the model and start training with early stopping and checkpointing

EVALUATION_INTERVAL = 150
EPOCHS = 500
history = ED_lstm_model.fit(train_data_multi, epochs=EPOCHS,
steps_per_epoch=EVALUATION_INTERVAL,validation_data=val_data_multi,
validation_steps=50,verbose =1,callbacks =[tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='min'),
    tf.keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', 
    save_best_only=True, mode='min', verbose=0)])
# Out:
# Epoch 1/500
# 150/150 [==============================] - 12s 43ms/step - loss: 0.0968 - val_loss: 0.0523
# Epoch 2/500
# 150/150 [==============================] - 5s 32ms/step - loss: 0.0450 - val_loss: 0.0127
# Epoch 3/500
# 150/150 [==============================] - 5s 31ms/step - loss: 0.0094 - val_loss: 0.0110
# Epoch 4/500
# 150/150 [==============================] - 5s 32ms/step - loss: 0.0081 - val_loss: 0.0095
# Epoch 5/500
# 150/150 [==============================] - 5s 31ms/step - loss: 0.0077 - val_loss: 0.0082
# Epoch 6/500
# 150/150 [==============================] - 5s 32ms/step - loss: 0.0072 - val_loss: 0.0094
# Epoch 7/500
# 150/150 [==============================] - 5s 31ms/step - loss: 0.0067 - val_loss: 0.0120
# Epoch 8/500
# 150/150 [==============================] - 5s 31ms/step - loss: 0.0067 - val_loss: 0.0107
# Epoch 9/500
# 150/150 [==============================] - 5s 31ms/step - loss: 0.0068 - val_loss: 0.0075
# Epoch 10/500
# 150/150 [==============================] - 5s 32ms/step - loss: 0.0062 - val_loss: 0.0077
# Epoch 11/500
# 150/150 [==============================] - 5s 31ms/step - loss: 0.0062 - val_loss: 0.0084
# Epoch 12/500
# 150/150 [==============================] - 5s 32ms/step - loss: 0.0063 - val_loss: 0.0064
# Epoch 13/500
# 150/150 [==============================] - 5s 31ms/step - loss: 0.0058 - val_loss: 0.0079
# Epoch 14/500
# 150/150 [==============================] - 5s 31ms/step - loss: 0.0059 - val_loss: 0.0120
# Epoch 15/500
# 150/150 [==============================] - 5s 32ms/step - loss: 0.0056 - val_loss: 0.0111
# Epoch 16/500
# 150/150 [==============================] - 5s 32ms/step - loss: 0.0056 - val_loss: 0.0088
# Epoch 17/500
# 150/150 [==============================] - 5s 32ms/step - loss: 0.0050 - val_loss: 0.0074
# Epoch 18/500
# 150/150 [==============================] - 5s 32ms/step - loss: 0.0050 - val_loss: 0.0079
# Epoch 19/500
# 150/150 [==============================] - 5s 31ms/step - loss: 0.0053 - val_loss: 0.0065
# Epoch 20/500
# 150/150 [==============================] - 5s 32ms/step - loss: 0.0050 - val_loss: 0.0079
# Epoch 21/500
# 150/150 [==============================] - 5s 31ms/step - loss: 0.0047 - val_loss: 0.0104
# Epoch 22/500
# 150/150 [==============================] - 5s 31ms/step - loss: 0.0043 - val_loss: 0.0103
# Epoch 00022: early stopping

# %%
# Load the best weights into the model
Trained_model = tf.keras.models.load_model(model_path)

# %%
# Plot the loss and val_loss against the epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'],color='red')
plt.title('Model loss',size=14,fontweight='bold')
plt.ylabel('Loss',size=12,fontweight='semibold')
plt.xlabel('Epoch',size=12,fontweight='semibold')
plt.legend(['Train loss', 'Validation loss'])
plt.figure(figsize=(16,9))
plt.show()

# %%
# Check the model summary
Trained_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 90, 40)            7520
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 90, 20)            4880
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 15)                2160
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 1, 15)             0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 1, 40)             8960
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 1, 25)             6600
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 1, 1)              26
# =================================================================
# Total params: 30,146
# Trainable params: 30,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
# predictions for AutoEncoder

predictions = []
for i in x_test_multi:
    # predict the daily streamflow
    i_reshape = i.reshape(1, i.shape[0], i.shape[1])
    Predicted_results = Trained_model.predict(i_reshape)
    # store the predictions
    predictions.append(Predicted_results)
print(predictions[0])
# Out:
# [[[0.5422973]]]

# %%
# convert prediction list to numpy array
predictions = np.array(predictions).reshape(-1, 1)
print(predictions.shape)
# Out:
# (1046, 1)

# %%
# Rescale the predicted values back to the original scale.

predictions_Inv_trans = scaler.inverse_transform(predictions)
print(predictions_Inv_trans[0])
print(predictions_Inv_trans.shape)
print(len(predictions_Inv_trans))
# Out:
# [336.76663]
# (1046, 1)
# 1046

# %%
# Define the time-series evaluation function

def timeseries_evaluation_metrics_func(y_true, y_pred):
    kgeprime, r, gamma, beta = he.kgeprime(y_pred, y_true)
    kge, r, alpha, beta = he.kge(y_pred, y_true)
    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'NSE is : {he.nse(np.array(y_pred), np.array(y_true))}')
    print(f"KGE' is : {kgeprime}")
    print(f'r is : {r}, gamma is : {gamma}')
    print(f'KGE is : {kge}')
    print(f'alpha is : {alpha}, beta is : {beta}')
    print(f'PBIAS is : {he.pbias(np.array(y_pred), np.array(y_true))}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MARE is : {he.mare(np.array(y_pred), np.array(y_true))}')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}') 
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')
timeseries_evaluation_metrics_func(validate['H'].values.reshape(-1, 1),predictions_Inv_trans)
# Out:
# Evaluation metric results:-
# NSE is : [0.86006225]
# KGE' is : [0.88430601]
# r is : [0.94754154], gamma is : [0.98096572]
# KGE is : [0.83552093]
# alpha is : [0.8815493], beta is : [0.89865453]
# PBIAS is : [10.13454721]
# RMSE is : 58.73952917632115
# MARE is : [0.15381944]
# MSE is : 3450.3322878558834
# MAE is : 43.56707659004751
# MAPE is : 21.840725983419244
# R2 is : 0.860062246751012

# %%
# Plot the Observed versus predicted values.
plt.plot( list(validate['H'] / 100))
plt.plot( list(predictions_Inv_trans / 100),color='red')
plt.title("Observed vs Predicted",size=14,fontweight='bold')
plt.ylabel("Water Level (m)",size=12,fontweight='semibold')
plt.legend(('Observed','Predicted'))
plt.figure(figsize=(16,9))
plt.show()

# %%
# save GPM IMERGE train loss and val loss to CSV
df_history = pd.DataFrame.from_records([history.history['loss'],history.history['val_loss']], index=['train_loss', 'val_loss']).transpose()
df_history.to_csv('/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/ED_LSTM_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax_history.csv', index=False)

# %%
# 5th Model
# CNN Model

# import all libraries and modules
import tensorflow as tf # deep learning api
import pandas as pd  # for data manipulation
import numpy as np    # for mathematical calculation
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Conv1D, MaxPool1D, Dropout
from tensorflow.keras.layers import Dense, Flatten
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.preprocessing import QuantileTransformer, StandardScaler, MinMaxScaler
tf.random.set_seed(123)
np.random.seed(123)
import datetime
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import set_config
import hydroeval as he

# %%
# Prepare the training and validation time-series data
BATCH_SIZE = 256
BUFFER_SIZE = 150
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
# Define the CNN model

CNN_model = Sequential()
CNN_model.add(Conv1D(filters=64, kernel_size=3, activation='swish',
input_shape=(x_train_multi.shape[1], x_train_multi.shape[2])))
CNN_model.add(MaxPool1D(pool_size=2))
CNN_model.add(Dropout(0.2))
CNN_model.add(Flatten())
CNN_model.add(Dense(30, activation='swish'))
CNN_model.add(Dropout(0.2))
CNN_model.add(Dense(horizon))
CNN_model.compile(optimizer='adam', loss='mse')

# %%
# the best weights are stored in model path
model_path = r'/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/CNN_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax.h5'

# %%
# Configure the model and start training with early stopping and checkpointing

EVALUATION_INTERVAL = 150
EPOCHS = 500
history = CNN_model.fit(train_data_multi, epochs=EPOCHS,
steps_per_epoch=EVALUATION_INTERVAL,validation_data=val_data_multi,
validation_steps=50,verbose =1,callbacks =[tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='min'),
    tf.keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', 
    save_best_only=True, mode='min', verbose=0)])
# Out:
# Epoch 1/500
# 150/150 [==============================] - 3s 14ms/step - loss: 0.0439 - val_loss: 0.0152
# Epoch 2/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0119 - val_loss: 0.0099
# Epoch 3/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0107 - val_loss: 0.0090
# Epoch 4/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0102 - val_loss: 0.0110
# Epoch 5/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0105 - val_loss: 0.0093
# Epoch 6/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0098 - val_loss: 0.0115
# Epoch 7/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0091 - val_loss: 0.0158
# Epoch 8/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0098 - val_loss: 0.0168
# Epoch 9/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0091 - val_loss: 0.0105
# Epoch 10/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0083 - val_loss: 0.0075
# Epoch 11/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0088 - val_loss: 0.0103
# Epoch 12/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0083 - val_loss: 0.0083
# Epoch 13/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0082 - val_loss: 0.0107
# Epoch 14/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0076 - val_loss: 0.0144
# Epoch 15/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0080 - val_loss: 0.0147
# Epoch 16/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0075 - val_loss: 0.0098
# Epoch 17/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 18/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0071 - val_loss: 0.0079
# Epoch 19/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0072 - val_loss: 0.0079
# Epoch 20/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0069 - val_loss: 0.0093
# Epoch 21/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0067 - val_loss: 0.0125
# Epoch 22/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0067 - val_loss: 0.0127
# Epoch 23/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0065 - val_loss: 0.0083
# Epoch 24/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0064 - val_loss: 0.0067
# Epoch 25/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0060 - val_loss: 0.0076
# Epoch 26/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0064 - val_loss: 0.0075
# Epoch 27/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0061 - val_loss: 0.0087
# Epoch 28/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0058 - val_loss: 0.0099
# Epoch 29/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0056 - val_loss: 0.0104
# Epoch 30/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 31/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0055 - val_loss: 0.0068
# Epoch 32/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0054 - val_loss: 0.0085
# Epoch 33/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0055 - val_loss: 0.0074
# Epoch 34/500
# 150/150 [==============================] - 1s 5ms/step - loss: 0.0051 - val_loss: 0.0082
# Epoch 00034: early stopping

# %%
# Load the best weights into the model
Trained_model = tf.keras.models.load_model(model_path)

# %%
# Plot the loss and val_loss against the epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'],color='red')
plt.title('Model loss',size=14,fontweight='bold')
plt.ylabel('Loss',size=12,fontweight='semibold')
plt.xlabel('Epoch',size=12,fontweight='semibold')
plt.legend(['train loss', 'validation loss'])
plt.figure(figsize=(16,9))
plt.show()

# %%
# Check the model summary
Trained_model.summary()

# Prepare test dataset
x_test_multi, y_test_multi = custom_ts_multi_data_prep(
    validateX, validateY, 0, None, hist_window, horizon)
print ('Single window of past history')
print(x_test_multi[0])
print ('\n Target horizon')
print (y_test_multi[0])
print(len(y_test_multi))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 88, 64)            1216
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 44, 64)            0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 44, 64)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2816)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 30)                84510
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 85,757
# Trainable params: 85,757
# Non-trainable params: 0
# _________________________________________________________________
# Single window of past history
# [[0.64915934 0.51788998 0.50394085 0.54875995 0.48451139 0.55653959]
#  [0.66851684 0.51928518 0.50724615 0.53032186 0.48381069 0.55811863]
#  [0.54069849 0.52059811 0.51472431 0.54105049 0.49073204 0.55994025]
#  [0.52520375 0.52401377 0.54135239 0.56337311 0.50812177 0.56186623]
#  [0.66006713 0.52893511 0.47215419 0.58106726 0.50600073 0.5630003 ]
#  [0.61980647 0.53002511 0.46396184 0.58793935 0.49413503 0.56430323]
#  [0.54690516 0.53147397 0.46821193 0.59788748 0.4860022  0.56561089]
#  [0.61902648 0.53397592 0.48774495 0.59145644 0.48348732 0.5669316 ]
#  [0.67112889 0.53601291 0.50781313 0.61116535 0.48241117 0.56889276]
#  [0.68589755 0.53896876 0.4921757  0.63706688 0.4765243  0.57056298]
#  [0.56129766 0.54245054 0.46668908 0.6586765  0.47573379 0.57210809]
#  [0.56728687 0.54405029 0.46664991 0.68718521 0.47622433 0.57377269]
#  [0.6279826  0.54618582 0.48326568 0.6400578  0.47883479 0.57541952]
#  [0.69510202 0.54890682 0.47983288 0.66274938 0.47749432 0.57757889]
#  [0.55532396 0.55204648 0.49452259 0.63878804 0.4761236  0.57976763]
#  [0.67412849 0.55600653 0.51953884 0.6730877  0.47924914 0.58169482]
#  [0.58032815 0.55907807 0.50989923 0.69084054 0.48659457 0.58329341]
#  [0.57130456 0.56428773 0.4980638  0.69530802 0.49404529 0.58517274]
#  [0.57839014 0.57028523 0.47687952 0.64342723 0.49247268 0.58687371]
#  [0.63571295 0.57765844 0.46164008 0.6036405  0.4866928  0.58831042]
#  [0.55173465 0.58420085 0.46408805 0.60183037 0.48072358 0.58992727]
#  [0.55780681 0.58888451 0.46792518 0.59711737 0.47421401 0.59129322]
#  [0.70483986 0.59107442 0.51070297 0.58742963 0.47426649 0.59289826]
#  [0.62151654 0.59412013 0.53588486 0.62353826 0.47763443 0.59394873]
#  [0.62601151 0.60146472 0.50034403 0.67631287 0.48126954 0.59492966]
#  [0.61528415 0.60465402 0.49515135 0.6676339  0.48832725 0.59597146]
#  [0.57990737 0.60770317 0.50284464 0.62045687 0.4976558  0.59727229]
#  [0.67547211 0.6085577  0.52255745 0.61884941 0.50869681 0.59953491]
#  [0.58712816 0.60957509 0.55627722 0.61774979 0.51724431 0.60381231]
#  [0.55225465 0.61083837 0.55107509 0.64996589 0.51988692 0.60781009]
#  [0.52594773 0.61394977 0.55560827 0.70687168 0.53216134 0.61355792]
#  [0.66283547 0.61709787 0.55383039 0.66166069 0.54355102 0.61863243]
#  [0.72031863 0.6239795  0.51910348 0.6584848  0.54695411 0.62235476]
#  [0.58143936 0.62736774 0.53426865 0.63055997 0.54925311 0.62548166]
#  [0.59834375 0.6364679  0.5548824  0.6318296  0.54895604 0.62794657]
#  [0.58707765 0.63905912 0.54470415 0.7175049  0.54765525 0.63080934]
#  [0.59412293 0.63962692 0.55250803 0.78540487 0.54707957 0.63386023]
#  [0.63772876 0.64141847 0.54895718 0.73485033 0.54590475 0.63647394]
#  [0.60577411 0.64360146 0.53403673 0.7375977  0.54915015 0.63790182]
#  [0.64697514 0.64588551 0.51991038 0.74843564 0.54608377 0.63939684]
#  [0.67204983 0.64769538 0.53589334 0.75751097 0.54287532 0.64153691]
#  [0.68768061 0.6504107  0.53534062 0.72607564 0.54120725 0.64304374]
#  [0.63411419 0.65125517 0.54343039 0.67040861 0.53970187 0.64518797]
#  [0.6164324  0.65304627 0.55188167 0.66406013 0.54017844 0.64688487]
#  [0.71459933 0.6569355  0.54585551 0.5928503  0.54222966 0.64850532]
#  [0.68086246 0.66225272 0.51357178 0.61664653 0.54105101 0.64902896]
#  [0.59989713 0.66309721 0.54301636 0.65323996 0.54225711 0.65076377]
#  [0.60988381 0.66346377 0.55191284 0.6456089  0.54502383 0.65179231]
#  [0.68163855 0.66364288 0.56651317 0.60178441 0.55016963 0.65272263]
#  [0.59780629 0.66377261 0.54613792 0.63913534 0.54931068 0.65283635]
#  [0.62531442 0.66517372 0.54040076 0.67443372 0.54823683 0.65285431]
#  [0.64713052 0.66526449 0.52471938 0.68166873 0.55030118 0.6530924 ]
#  [0.62927657 0.66543437 0.54905829 0.68234738 0.55090266 0.65431705]
#  [0.58610379 0.6662205  0.52928653 0.6236318  0.54715911 0.65514609]
#  [0.55287853 0.66653508 0.51967537 0.66745349 0.5384858  0.65478927]
#  [0.85867771 0.66709924 0.50793118 0.75442392 0.53034127 0.65374083]
#  [0.68677654 0.66719489 0.54708097 0.7568305  0.53186299 0.65365876]
#  [0.63220172 0.6674735  0.55882275 0.65048362 0.53873039 0.65398021]
#  [0.63064925 0.66779435 0.56012709 0.62253424 0.54089531 0.6543536 ]
#  [0.62998532 0.66864358 0.55182581 0.66107293 0.54467427 0.6548061 ]
#  [0.6243712  0.66904154 0.55124237 0.75195124 0.55059186 0.65544662]
#  [0.60284478 0.66923812 0.54934523 0.70585722 0.55713216 0.65583315]
#  [0.70907988 0.66926284 0.55105404 0.70511388 0.5576814  0.65630645]
#  [0.79560102 0.66908137 0.54697586 0.68252892 0.55555642 0.65670936]
#  [0.59297523 0.66681974 0.55022649 0.63971477 0.55382602 0.65756791]
#  [0.6020332  0.66683665 0.53004003 0.65322871 0.55054106 0.65783085]
#  [0.67483752 0.66706752 0.49765002 0.63771308 0.54028324 0.65724473]
#  [0.64114888 0.66776777 0.48903685 0.5887336  0.52756773 0.65576668]
#  [0.66939831 0.6686235  0.51053082 0.584178   0.51915331 0.65635654]
#  [0.68492647 0.67289635 0.51313517 0.56711046 0.51243977 0.65985284]
#  [0.59355798 0.67366485 0.53118458 0.53780873 0.50928302 0.66468249]
#  [0.59093064 0.67539242 0.50926515 0.50594807 0.50610029 0.66764875]
#  [0.63108983 0.67395599 0.49366423 0.54780241 0.50557645 0.6691418 ]
#  [0.60237933 0.67175114 0.48592652 0.62407175 0.50486444 0.66920223]
#  [0.63272589 0.67131014 0.47029019 0.58243471 0.49631282 0.66905911]
#  [0.63141085 0.67150293 0.47105942 0.54646709 0.48742764 0.66899186]
#  [0.6542895  0.67203171 0.47056351 0.56974899 0.4784803  0.66828483]
#  [0.66934148 0.67087412 0.47024342 0.56279308 0.4737465  0.66805643]
#  [0.66927744 0.67188876 0.47179173 0.55606435 0.47088278 0.66703552]
#  [0.70528535 0.67181576 0.46666297 0.50229308 0.46800884 0.66562465]
#  [0.61341611 0.67159537 0.46036797 0.55369327 0.46620442 0.66337366]
#  [0.55164157 0.67154043 0.45351859 0.56584115 0.46365305 0.65969437]
#  [0.56865932 0.67113119 0.44951975 0.57258687 0.46028732 0.65640698]
#  [0.60108842 0.67102449 0.44902833 0.52940967 0.45753914 0.65207006]
#  [0.57288051 0.67125955 0.45350941 0.55345978 0.45525199 0.64806235]
#  [0.58122761 0.67209027 0.45491841 0.56975822 0.45373188 0.64520328]
#  [0.54252192 0.67224635 0.44626622 0.56752349 0.4516861  0.64170552]
#  [0.54728031 0.6708036  0.43944952 0.57244386 0.44954402 0.6369877 ]
#  [0.55085063 0.67055589 0.44247301 0.57785308 0.44825917 0.63344109]
#  [0.56857369 0.67081459 0.44555357 0.57325902 0.44753629 0.63018083]]
#
#  Target horizon
# [[0.56360709]]
# 1046

# %%
# predictions for CNN

predictions = []
for i in x_test_multi:
    # predict the daily streamflow
    i_reshape = i.reshape(1, i.shape[0], i.shape[1])
    Predicted_results = Trained_model.predict(i_reshape)
    # store the predictions
    predictions.append(Predicted_results)
print(predictions[0])
# Out:
# [[0.51849854]]

# %%
# convert prediction list to numpy array
predictions = np.array(predictions).reshape(-1, 1)
print(predictions.shape)
# Out:
# (1046, 1)

# %%
# Rescale the predicted values back to the original scale.

predictions_Inv_trans = scaler.inverse_transform(predictions)
print(predictions_Inv_trans[0])
print(predictions_Inv_trans.shape)
print(len(predictions_Inv_trans))
# Out:
# [321.98758]
# (1046, 1)
# 1046

# %%
# Define the time-series evaluation function

def timeseries_evaluation_metrics_func(y_true, y_pred):
    kgeprime, r, gamma, beta = he.kgeprime(y_pred, y_true)
    kge, r, alpha, beta = he.kge(y_pred, y_true)
    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'NSE is : {he.nse(np.array(y_pred), np.array(y_true))}')
    print(f"KGE' is : {kgeprime}")
    print(f'r is : {r}, gamma is : {gamma}')
    print(f'KGE is : {kge}')
    print(f'alpha is : {alpha}, beta is : {beta}')
    print(f'PBIAS is : {he.pbias(np.array(y_pred), np.array(y_true))}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MARE is : {he.mare(np.array(y_pred), np.array(y_true))}')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}') 
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')
timeseries_evaluation_metrics_func(validate['H'].values.reshape(-1, 1),predictions_Inv_trans)
# Out:
# Evaluation metric results:-
# NSE is : [0.86926676]
# KGE' is : [0.90776293]
# r is : [0.94109221], gamma is : [1.00442406]
# KGE is : [0.88624326]
# alpha is : [0.93327302], beta is : [0.92916232]
# PBIAS is : [7.08376826]
# RMSE is : 56.77485449091619
# MARE is : [0.15020708]
# MSE is : 3223.3841024647063
# MAE is : 42.54392915975523
# MAPE is : 18.517491652370094
# R2 is : 0.8692667570758165

# %%
# Plot the Observed versus predicted values.
plt.plot( list(validate['H'] / 100))
plt.plot( list(predictions_Inv_trans / 100),color='red')
plt.title("Observed vs Predicted",size=14,fontweight='bold')
plt.ylabel("Water Level (m)",size=12,fontweight='semibold')
plt.legend(('Observed','Predicted'))
plt.figure(figsize=(16,9))
plt.show()

# %%
# save GPM IMERGE train loss and val loss to CSV
df_history = pd.DataFrame.from_records([history.history['loss'],history.history['val_loss']], index=['train_loss', 'val_loss']).transpose()
df_history.to_csv('/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/CNN_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax_history.csv', index=False)

# %%
# 6th Model
# LSTM Model

# import all libraries and modules
import tensorflow as tf # deep learning api
import pandas as pd  # for data manipulation
import numpy as np    # for mathematical calculation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout
from tensorflow.keras.layers import Dense, Flatten
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.preprocessing import QuantileTransformer, StandardScaler, MinMaxScaler
tf.random.set_seed(123)
np.random.seed(123)
import datetime
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import set_config
import hydroeval as he

# %%
# Prepare the training and validation time-series data
BATCH_SIZE = 256
BUFFER_SIZE = 150
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
# Define the LSTM model

lstm_multi = Sequential()
lstm_multi.add(LSTM(
    150,activation='tanh',input_shape=x_train_multi.shape[-2:],return_sequences=True))
lstm_multi.add(Dropout(0.2)),
lstm_multi.add(LSTM(units=100,activation='tanh',return_sequences=False)),
lstm_multi.add(Dropout(0.2)),
lstm_multi.add(Dense(units=horizon)),
lstm_multi.compile(optimizer='adam', loss='mse')

# %%
# the best weights are stored in model path
model_path = r'/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/LSTM_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax.h5'

# %%
# Configure the model and start training with early stopping and checkpointing

EVALUATION_INTERVAL = 150
EPOCHS = 500
history = lstm_multi.fit(train_data_multi, epochs=EPOCHS,
steps_per_epoch=EVALUATION_INTERVAL,validation_data=val_data_multi,
validation_steps=50,verbose =1,callbacks =[tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='min'),
    tf.keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', 
    save_best_only=True, mode='min', verbose=0)])
# Out:
# Epoch 1/500
# 150/150 [==============================] - 10s 52ms/step - loss: 0.0252 - val_loss: 0.0159
# Epoch 2/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0126 - val_loss: 0.0109
# Epoch 3/500
# 150/150 [==============================] - 7s 45ms/step - loss: 0.0117 - val_loss: 0.0161
# Epoch 4/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0117 - val_loss: 0.0113
# Epoch 5/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0106 - val_loss: 0.0082
# Epoch 6/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0112 - val_loss: 0.0100
# Epoch 7/500
# 150/150 [==============================] - 7s 45ms/step - loss: 0.0097 - val_loss: 0.0111
# Epoch 8/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0082 - val_loss: 0.0120
# Epoch 9/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0083 - val_loss: 0.0098
# Epoch 10/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0082 - val_loss: 0.0107
# Epoch 11/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0079 - val_loss: 0.0079
# Epoch 12/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0074 - val_loss: 0.0082
# Epoch 13/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0068 - val_loss: 0.0087
# Epoch 14/500
# 150/150 [==============================] - 7s 45ms/step - loss: 0.0064 - val_loss: 0.0116
# Epoch 15/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0065 - val_loss: 0.0118
# Epoch 16/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0064 - val_loss: 0.0076
# Epoch 17/500
# 150/150 [==============================] - 7s 45ms/step - loss: 0.0056 - val_loss: 0.0074
# Epoch 18/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0053 - val_loss: 0.0088
# Epoch 19/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0056 - val_loss: 0.0075
# Epoch 20/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0052 - val_loss: 0.0087
# Epoch 21/500
# 150/150 [==============================] - 7s 45ms/step - loss: 0.0049 - val_loss: 0.0079
# Epoch 22/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0049 - val_loss: 0.0102
# Epoch 23/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0048 - val_loss: 0.0083
# Epoch 24/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0043 - val_loss: 0.0072
# Epoch 25/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0042 - val_loss: 0.0083
# Epoch 26/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0045 - val_loss: 0.0060
# Epoch 27/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0040 - val_loss: 0.0082
# Epoch 28/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0041 - val_loss: 0.0092
# Epoch 29/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0041 - val_loss: 0.0097
# Epoch 30/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0043 - val_loss: 0.0081
# Epoch 31/500
# 150/150 [==============================] - 7s 45ms/step - loss: 0.0036 - val_loss: 0.0079
# Epoch 32/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0036 - val_loss: 0.0088
# Epoch 33/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0036 - val_loss: 0.0086
# Epoch 34/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0038 - val_loss: 0.0072
# Epoch 35/500
# 150/150 [==============================] - 7s 45ms/step - loss: 0.0034 - val_loss: 0.0086
# Epoch 36/500
# 150/150 [==============================] - 7s 46ms/step - loss: 0.0035 - val_loss: 0.0093
# Epoch 00036: early stopping

# %%
# Load the best weights into the model
Trained_model = tf.keras.models.load_model(model_path)

# %%
# Plot the loss and val_loss against the epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'],color='red')
plt.title('Model loss',size=14,fontweight='bold')
plt.ylabel('Loss',size=12,fontweight='semibold')
plt.xlabel('Epoch',size=12,fontweight='semibold')
plt.legend(['Train loss', 'Validation loss'])
plt.figure(figsize=(16,9))
plt.show()

# %%
# Check the model summary
Trained_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 90, 150)           94200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 90, 150)           0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 100)               100400
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 194,701
# Trainable params: 194,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
# predictions for LSTM

predictions = []
for i in x_test_multi:
    # predict the daily streamflow
    i_reshape = i.reshape(1, i.shape[0], i.shape[1])
    Predicted_results = Trained_model.predict(i_reshape)
    # store the predictions
    predictions.append(Predicted_results)
print(predictions[0])
# Out:
# [[0.53458714]]

# %%
# convert prediction list to numpy array
predictions = np.array(predictions).reshape(-1, 1)
print(predictions.shape)
# Out:
# (1046, 1)

# %%
# Rescale the predicted values back to the original scale.

predictions_Inv_trans = scaler.inverse_transform(predictions)
print(predictions_Inv_trans[0])
print(predictions_Inv_trans.shape)
print(len(predictions_Inv_trans))
# Out:
# [331.9786]
# (1046, 1)
# 1046

# %%
# correct evaluation metrics

# Define the time-series evaluation function

def timeseries_evaluation_metrics_func(y_true, y_pred):
    kgeprime, r, gamma, beta = he.kgeprime(y_pred, y_true)
    kge, r, alpha, beta = he.kge(y_pred, y_true)
    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'NSE is : {he.nse(np.array(y_pred), np.array(y_true))}')
    print(f"KGE' is : {kgeprime}")
    print(f'r is : {r}, gamma is : {gamma}')
    print(f'KGE is : {kge}')
    print(f'alpha is : {alpha}, beta is : {beta}')
    print(f'PBIAS is : {he.pbias(np.array(y_pred), np.array(y_true))}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MARE is : {he.mare(np.array(y_pred), np.array(y_true))}')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}') 
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')
timeseries_evaluation_metrics_func(validate['H'].values.reshape(-1, 1),predictions_Inv_trans)
# Out:
# Evaluation metric results:-
# NSE is : [0.88360252]
# KGE' is : [0.91762567]
# r is : [0.94688967], gamma is : [0.99998326]
# KGE is : [0.89630658]
# alpha is : [0.9370175], beta is : [0.93703316]
# PBIAS is : [6.29668424]
# RMSE is : 53.5716226828845
# MARE is : [0.13299528]
# MSE is : 2869.918756877345
# MAE is : 37.668942715880064
# MAPE is : 21.295014342135424
# R2 is : 0.8836025201810014

# %%
# Plot the Observed versus predicted values.
plt.plot( list(validate['H'] / 100))
plt.plot( list(predictions_Inv_trans / 100),color='red')
plt.title("Observed vs Predicted",size=14,fontweight='bold')
plt.ylabel("Water Level (m)",size=12,fontweight='semibold')
plt.legend(('Observed','Predicted'))
plt.figure(figsize=(16,9))
plt.show()

# %%
# save GPM IMERGE train loss and val loss to CSV
df_history = pd.DataFrame.from_records([history.history['loss'],history.history['val_loss']], index=['train_loss', 'val_loss']).transpose()
df_history.to_csv('/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/LSTM_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax_history.csv', index=False)

# %%
# 7th Model
# GRU Model

# import all libraries and modules
import tensorflow as tf # deep learning api
import pandas as pd  # for data manipulation
import numpy as np    # for mathematical calculation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dropout
from tensorflow.keras.layers import Dense, Flatten
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.preprocessing import QuantileTransformer, StandardScaler, MinMaxScaler
tf.random.set_seed(123)
np.random.seed(123)
import datetime
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import set_config
import hydroeval as he

# %%
# # Define the GRU model

GRU_model = Sequential([
    GRU(100, activation='tanh', input_shape=x_train_multi.shape[-2:],return_sequences=True),
    Dropout(0.2),
    GRU(units=50,activation='tanh', return_sequences=False),
    Dropout(0.2),
    Dense(units=horizon),
])
GRU_model.compile(optimizer='adam', loss='mse')

# %%
# the best weights are stored in model path
model_path = r'/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/GRU_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax.h5'

# %%
# Configure the model and start training with early stopping and checkpointing

EVALUATION_INTERVAL = 150
EPOCHS = 500
history = GRU_model.fit(train_data_multi, epochs=EPOCHS,
steps_per_epoch=EVALUATION_INTERVAL,validation_data=val_data_multi,
validation_steps=50,verbose =1,callbacks =[tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='min'),
    tf.keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', 
    save_best_only=True, mode='min', verbose=0)])
# Out:
# Epoch 1/500
# 150/150 [==============================] - 8s 36ms/step - loss: 0.0445 - val_loss: 0.0141
# Epoch 2/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0131 - val_loss: 0.0109
# Epoch 3/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0117 - val_loss: 0.0105
# Epoch 4/500
# 150/150 [==============================] - 5s 30ms/step - loss: 0.0112 - val_loss: 0.0124
# Epoch 5/500
# 150/150 [==============================] - 5s 30ms/step - loss: 0.0113 - val_loss: 0.0100
# Epoch 6/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0108 - val_loss: 0.0097
# Epoch 7/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0099 - val_loss: 0.0121
# Epoch 8/500
# 150/150 [==============================] - 5s 30ms/step - loss: 0.0096 - val_loss: 0.0130
# Epoch 9/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0085 - val_loss: 0.0096
# Epoch 10/500
# 150/150 [==============================] - 5s 30ms/step - loss: 0.0076 - val_loss: 0.0087
# Epoch 11/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0073 - val_loss: 0.0087
# Epoch 12/500
# 150/150 [==============================] - 5s 30ms/step - loss: 0.0077 - val_loss: 0.0075
# Epoch 13/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0070 - val_loss: 0.0088
# Epoch 14/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0068 - val_loss: 0.0115
# Epoch 15/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0066 - val_loss: 0.0121
# Epoch 16/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0064 - val_loss: 0.0101
# Epoch 17/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0058 - val_loss: 0.0075
# Epoch 18/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0058 - val_loss: 0.0071
# Epoch 19/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0056 - val_loss: 0.0072
# Epoch 20/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0054 - val_loss: 0.0079
# Epoch 21/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0050 - val_loss: 0.0099
# Epoch 22/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0050 - val_loss: 0.0108
# Epoch 23/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0048 - val_loss: 0.0082
# Epoch 24/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0042 - val_loss: 0.0064
# Epoch 25/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0041 - val_loss: 0.0068
# Epoch 26/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0041 - val_loss: 0.0078
# Epoch 27/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0039 - val_loss: 0.0087
# Epoch 28/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0037 - val_loss: 0.0093
# Epoch 29/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0037 - val_loss: 0.0101
# Epoch 30/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0038 - val_loss: 0.0101
# Epoch 31/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0034 - val_loss: 0.0076
# Epoch 32/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0039 - val_loss: 0.0066
# Epoch 33/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0035 - val_loss: 0.0062
# Epoch 34/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0032 - val_loss: 0.0067
# Epoch 35/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0031 - val_loss: 0.0084
# Epoch 36/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0033 - val_loss: 0.0099
# Epoch 37/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0033 - val_loss: 0.0095
# Epoch 38/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0029 - val_loss: 0.0081
# Epoch 39/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0035 - val_loss: 0.0085
# Epoch 40/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0031 - val_loss: 0.0069
# Epoch 41/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0028 - val_loss: 0.0077
# Epoch 42/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0027 - val_loss: 0.0079
# Epoch 43/500
# 150/150 [==============================] - 4s 30ms/step - loss: 0.0030 - val_loss: 0.0079
# Epoch 00043: early stopping

# %%
# Load the best weights into the model
Trained_model = tf.keras.models.load_model(model_path)

# %%
# Plot the loss and val_loss against the epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'],color='red')
plt.title('Model loss',size=14,fontweight='bold')
plt.ylabel('Loss',size=12,fontweight='semibold')
plt.xlabel('Epoch',size=12,fontweight='semibold')
plt.legend(['Train loss', 'Validation loss'])
plt.figure(figsize=(16,9))
plt.show()

# %%
# Check the model summary
Trained_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (None, 90, 100)           32400
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 90, 100)           0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 50)                22800
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 55,251
# Trainable params: 55,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
# predictions for GRU

predictions = []
for i in x_test_multi:
    # predict the daily streamflow
    i_reshape = i.reshape(1, i.shape[0], i.shape[1])
    Predicted_results = Trained_model.predict(i_reshape)
    # store the predictions
    predictions.append(Predicted_results)
print(predictions[0])
# Out:
# [[0.5130445]]

# %%
# convert prediction list to numpy array
predictions = np.array(predictions).reshape(-1, 1)
print(predictions.shape)
# Out:
# (1046, 1)

# %%
# Rescale the predicted values back to the original scale.

predictions_Inv_trans = scaler.inverse_transform(predictions)
print(predictions_Inv_trans[0])
print(predictions_Inv_trans.shape)
print(len(predictions_Inv_trans))
# Out:
# [318.60062]
# (1046, 1)
# 1046

# %%
# Define the time-series evaluation function

def timeseries_evaluation_metrics_func(y_true, y_pred):
    kgeprime, r, gamma, beta = he.kgeprime(y_pred, y_true)
    kge, r, alpha, beta = he.kge(y_pred, y_true)
    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'NSE is : {he.nse(np.array(y_pred), np.array(y_true))}')
    print(f"KGE' is : {kgeprime}")
    print(f'r is : {r}, gamma is : {gamma}')
    print(f'KGE is : {kge}')
    print(f'alpha is : {alpha}, beta is : {beta}')
    print(f'PBIAS is : {he.pbias(np.array(y_pred), np.array(y_true))}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MARE is : {he.mare(np.array(y_pred), np.array(y_true))}')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}') 
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')
timeseries_evaluation_metrics_func(validate['H'].values.reshape(-1, 1),predictions_Inv_trans)
# Out:
# Evaluation metric results:-
# NSE is : [0.82381378]
# KGE' is : [0.90349443]
# r is : [0.90923571], gamma is : [0.97033955]
# KGE is : [0.89850116]
# alpha is : [0.95677465], beta is : [0.98602047]
# PBIAS is : [1.39795276]
# RMSE is : 65.90964627931206
# MARE is : [0.16542312]
# MSE is : 4344.081472664034
# MAE is : 46.853646531843545
# MAPE is : 28.68498863474722
# R2 is : 0.8238137806741727

# %%
# Plot the Observed versus predicted values.
plt.plot( list(validate['H'] / 100))
plt.plot( list(predictions_Inv_trans / 100),color='red')
plt.title("Observed vs Predicted",size=14,fontweight='bold')
plt.ylabel("Water Level (m)",size=12,fontweight='semibold')
plt.legend(('Observed','Predicted'))
plt.figure(figsize=(16,9))
plt.show()

# %%
# save GPM IMERGE train loss and val loss to CSV
df_history = pd.DataFrame.from_records([history.history['loss'],history.history['val_loss']], index=['train_loss', 'val_loss']).transpose()
df_history.to_csv('/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/GRU_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax_history.csv', index=False)

# %%
# 8th Model Bidirectional LSTM

# import all libraries and modules
import tensorflow as tf
import pandas as pd  # for data manipulation
import numpy as np    # for mathematical calculation
# import seaborn as sns   # for data visualisation
import matplotlib.pyplot as plt   # for plotting graph
# %matplotlib inline 
# matplotlib inline ensures command in cells bellow the cell that outputs a plot does not affect the plot
from sklearn import metrics
from sklearn.preprocessing import QuantileTransformer, StandardScaler, MinMaxScaler
tf.random.set_seed(123)
np.random.seed(123)
import warnings   # to ignore warnings
import datetime
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn import set_config
import hydroeval as he

# %%
# Prepare the training and validation time-series data
BATCH_SIZE = 256
BUFFER_SIZE = 150
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
# Define the Bidirectional LSTM model

Bi_lstm_model = tf.keras.models.Sequential([
tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(150, activation='tanh',
return_sequences=True), input_shape=x_train_multi.shape[-2:]),
tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(50, activation='tanh')),
tf.keras.layers.Dense(20, activation='swish'),
tf.keras.layers.Dropout(0.2),
tf.keras.layers.Dense(units=horizon),
])
Bi_lstm_model.compile(optimizer='adam', loss='mse')

# %%
# the best weights are stored in model path
model_path = r'/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/Bidirectional_LSTM_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax.h5'

# %%
# Configure the model and start training with early stopping and checkpointing

EVALUATION_INTERVAL = 150
EPOCHS = 500
history = Bi_lstm_model.fit(train_data_multi, epochs=EPOCHS,
steps_per_epoch=EVALUATION_INTERVAL,validation_data=val_data_multi,
validation_steps=50,verbose =1,callbacks =[tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='min'),
    tf.keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', 
    save_best_only=True, mode='min', verbose=0)])
# Out:
# Epoch 1/500
# 150/150 [==============================] - 19s 95ms/step - loss: 0.0285 - val_loss: 0.0138
# Epoch 2/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0125 - val_loss: 0.0084
# Epoch 3/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0102 - val_loss: 0.0074
# Epoch 4/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0094 - val_loss: 0.0083
# Epoch 5/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0091 - val_loss: 0.0072
# Epoch 6/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0090 - val_loss: 0.0087
# Epoch 7/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0082 - val_loss: 0.0103
# Epoch 8/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0075 - val_loss: 0.0102
# Epoch 9/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0074 - val_loss: 0.0070
# Epoch 10/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 11/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0068 - val_loss: 0.0064
# Epoch 12/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0063 - val_loss: 0.0079
# Epoch 13/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0060 - val_loss: 0.0087
# Epoch 14/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0061 - val_loss: 0.0105
# Epoch 15/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0056 - val_loss: 0.0107
# Epoch 16/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0059 - val_loss: 0.0089
# Epoch 17/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0052 - val_loss: 0.0069
# Epoch 18/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0048 - val_loss: 0.0064
# Epoch 19/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0048 - val_loss: 0.0091
# Epoch 20/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0049 - val_loss: 0.0077
# Epoch 21/500
# 150/150 [==============================] - 13s 86ms/step - loss: 0.0043 - val_loss: 0.0084
# Epoch 00021: early stopping

# %%
# Load the best weights into the model
Trained_model = tf.keras.models.load_model(model_path)

# %%
# Plot the loss and val_loss against the epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'],color='red')
plt.title('Model loss',size=14,fontweight='bold')
plt.ylabel('Loss',size=12,fontweight='semibold')
plt.xlabel('Epoch',size=12,fontweight='semibold')
plt.legend(['Train loss', 'Validation loss'])
plt.figure(figsize=(16,9))
plt.show()

# %%
# Check the model summary
Trained_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 90, 300)           188400
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 100)               140400
# _________________________________________________________________
# dense_9 (Dense)              (None, 20)                2020
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 20)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 330,841
# Trainable params: 330,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions = []
for i in x_test_multi:
    # predict the hour
    i_reshape = i.reshape(1, i.shape[0], i.shape[1])
    Predicted_results = Trained_model.predict(i_reshape)
    # store the predictions
    predictions.append(Predicted_results)
print(predictions[0])
# Out:
# [[0.53702575]]

# %%
# convert prediction list to numpy array
predictions = np.array(predictions).reshape(-1, 1)
print(predictions.shape)
# Out:
# (1046, 1)

# %%
# Rescale the predicted values back to the original scale.

predictions_Inv_trans = scaler.inverse_transform(predictions)
print(predictions_Inv_trans[0])
print(predictions_Inv_trans.shape)
# Out:
# [333.49298]
# (1046, 1)

# %%
# correct evaluation metrics

# Define the time-series evaluation function

def timeseries_evaluation_metrics_func(y_true, y_pred):
    kgeprime, r, gamma, beta = he.kgeprime(y_pred, y_true)
    kge, r, alpha, beta = he.kge(y_pred, y_true)
    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'NSE is : {he.nse(np.array(y_pred), np.array(y_true))}')
    print(f"KGE' is : {kgeprime}")
    print(f'r is : {r}, gamma is : {gamma}')
    print(f'KGE is : {kge}')
    print(f'alpha is : {alpha}, beta is : {beta}')
    print(f'PBIAS is : {he.pbias(np.array(y_pred), np.array(y_true))}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MARE is : {he.mare(np.array(y_pred), np.array(y_true))}')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}') 
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')
timeseries_evaluation_metrics_func(validate['H'].values.reshape(-1, 1),predictions_Inv_trans)
# Out:
# Evaluation metric results:-
# NSE is : [0.89095591]
# KGE' is : [0.89223432]
# r is : [0.96199663], gamma is : [0.95189495]
# KGE is : [0.83614709]
# alpha is : [0.86752951], beta is : [0.91137106]
# PBIAS is : [8.86289443]
# RMSE is : 51.851828544031726
# MARE is : [0.14377047]
# MSE is : 2688.612123359663
# MAE is : 40.72085504003054
# MAPE is : 23.700817047142085
# R2 is : 0.8909559113407173

# %%
# Plot the Observed versus predicted values.
plt.plot( list(validate['H'] / 100))
plt.plot( list(predictions_Inv_trans / 100),color='red')
plt.title("Observed vs Predicted",size=14,fontweight='bold')
plt.ylabel("Water Level (m)",size=12,fontweight='semibold')
plt.legend(('Observed','Predicted'))
plt.figure(figsize=(16,9))
plt.show()

# %%
# save GPM IMERGE train loss and val loss to CSV
df_history = pd.DataFrame.from_records([history.history['loss'],history.history['val_loss']], index=['train_loss', 'val_loss']).transpose()
df_history.to_csv('/home/jefire/project/water/models/jiderebode_models/jide_h/jide_h_70_30_split/Bidirectional_LSTM_Multi_Jiderebode_H_1step_90days_gpm_tanh_swish_minmax_history.csv', index=False)
